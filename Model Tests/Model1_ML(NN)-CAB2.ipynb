# %% [markdown]
# # Neural Network Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the csv.
# # b1 view
# df = pd.read_csv("..\ML_Data_&_Preprocessing\b1_df.csv", index_col=[0])
# df.head()


# b2 view
df = pd.read_csv("../ML_Data_&_Preprocessing/ca_b2_df.csv", index_col=[0])
df.head()

# # b3 view
# df = pd.read_csv("..\ML_Data_&_Preprocessing\b3_df.csv", index_col=[0])
# df.head()
# Out:
#    spend  Impressions  leads  link_clicks  reach  Agency Tiers
# 0  40.27         1397      1           17   1320             4
# 1  50.27         2969      1           24   2766             4
# 2  63.96         3025      1           10   2818             4
# 3  88.15         4732      1           38   4497             4
# 4  54.42         1981      1           19   1792             4

# %%
df['leads'].value_counts()
# output shows we need to beat an accuracy score of .55 or higher
# Out:
# 1    9568
# 0    6464
# Name: leads, dtype: int64

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = df['leads'].values
X = df.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have X amount of columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 30
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 15
# layer 3 = hidden layer
layer3= 2

nn = tf.keras.models.Sequential()

### Activation functions
# https://www.tensorflow.org/api_docs/python/tf/keras/activations
    
# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="hard_sigmoid")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="elu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='elu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="hard_sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                180
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 2)                 32
#
#  dense_3 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 680
# Trainable params: 680
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.5273 - accuracy: 0.7533
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 376/376 [==============================] - 1s 736us/step - loss: 0.5250 - accuracy: 0.7542
# Epoch 2/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4613 - accuracy: 0.7888
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4602 - accuracy: 0.7893
# Epoch 3/100
# 366/376 [============================>.] - ETA: 0s - loss: 0.4576 - accuracy: 0.7915
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4563 - accuracy: 0.7918
# Epoch 4/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4533 - accuracy: 0.7932
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 376/376 [==============================] - 0s 726us/step - loss: 0.4525 - accuracy: 0.7937
# Epoch 5/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4466 - accuracy: 0.7951
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 376/376 [==============================] - 0s 730us/step - loss: 0.4459 - accuracy: 0.7957
# Epoch 6/100
# 365/376 [============================>.] - ETA: 0s - loss: 0.4445 - accuracy: 0.7947
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 376/376 [==============================] - 0s 727us/step - loss: 0.4428 - accuracy: 0.7958
# Epoch 7/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4372 - accuracy: 0.7983
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4394 - accuracy: 0.7968
# Epoch 8/100
# 366/376 [============================>.] - ETA: 0s - loss: 0.4390 - accuracy: 0.7976
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4380 - accuracy: 0.7981
# Epoch 9/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4336 - accuracy: 0.7988
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4338 - accuracy: 0.7985
# Epoch 10/100
# 366/376 [============================>.] - ETA: 0s - loss: 0.4512 - accuracy: 0.7809
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 376/376 [==============================] - 0s 724us/step - loss: 0.4509 - accuracy: 0.7816
# Epoch 11/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4385 - accuracy: 0.7933
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4394 - accuracy: 0.7921
# Epoch 12/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4312 - accuracy: 0.7976
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4300 - accuracy: 0.7986
# Epoch 13/100
# 360/376 [===========================>..] - ETA: 0s - loss: 0.4294 - accuracy: 0.7967
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4281 - accuracy: 0.7972
# Epoch 14/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4339 - accuracy: 0.7938
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 376/376 [==============================] - 0s 754us/step - loss: 0.4329 - accuracy: 0.7946
# Epoch 15/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4284 - accuracy: 0.7973
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 376/376 [==============================] - 0s 755us/step - loss: 0.4275 - accuracy: 0.7981
# Epoch 16/100
# 348/376 [==========================>...] - ETA: 0s - loss: 0.4270 - accuracy: 0.7966
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 376/376 [==============================] - 0s 765us/step - loss: 0.4271 - accuracy: 0.7972
# Epoch 17/100
# 354/376 [===========================>..] - ETA: 0s - loss: 0.4298 - accuracy: 0.7955
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 376/376 [==============================] - 0s 755us/step - loss: 0.4284 - accuracy: 0.7964
# Epoch 18/100
# 345/376 [==========================>...] - ETA: 0s - loss: 0.4279 - accuracy: 0.7986
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 376/376 [==============================] - 0s 773us/step - loss: 0.4268 - accuracy: 0.8001
# Epoch 19/100
# 351/376 [===========================>..] - ETA: 0s - loss: 0.4311 - accuracy: 0.7973
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 376/376 [==============================] - 0s 754us/step - loss: 0.4284 - accuracy: 0.7979
# Epoch 20/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4299 - accuracy: 0.8004
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 376/376 [==============================] - 0s 744us/step - loss: 0.4285 - accuracy: 0.8011
# Epoch 21/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4277 - accuracy: 0.7987
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4287 - accuracy: 0.7982
# Epoch 22/100
# 360/376 [===========================>..] - ETA: 0s - loss: 0.4252 - accuracy: 0.7977
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4249 - accuracy: 0.7981
# Epoch 23/100
# 368/376 [============================>.] - ETA: 0s - loss: 0.4256 - accuracy: 0.7978
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 376/376 [==============================] - 0s 722us/step - loss: 0.4254 - accuracy: 0.7983
# Epoch 24/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4342 - accuracy: 0.7960
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4346 - accuracy: 0.7958
# Epoch 25/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4356 - accuracy: 0.7915
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4431 - accuracy: 0.7824
# Epoch 26/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4734 - accuracy: 0.7650
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 376/376 [==============================] - 0s 756us/step - loss: 0.4710 - accuracy: 0.7675
# Epoch 27/100
# 349/376 [==========================>...] - ETA: 0s - loss: 0.4262 - accuracy: 0.7986
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 376/376 [==============================] - 0s 765us/step - loss: 0.4260 - accuracy: 0.7990
# Epoch 28/100
# 351/376 [===========================>..] - ETA: 0s - loss: 0.4269 - accuracy: 0.7970
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 376/376 [==============================] - 0s 754us/step - loss: 0.4254 - accuracy: 0.7982
# Epoch 29/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4237 - accuracy: 0.8002
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4253 - accuracy: 0.7990
# Epoch 30/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4253 - accuracy: 0.7997
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 376/376 [==============================] - 0s 725us/step - loss: 0.4254 - accuracy: 0.7996
# Epoch 31/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4234 - accuracy: 0.7998
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 376/376 [==============================] - 0s 733us/step - loss: 0.4238 - accuracy: 0.7993
# Epoch 32/100
# 354/376 [===========================>..] - ETA: 0s - loss: 0.4309 - accuracy: 0.7975
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4311 - accuracy: 0.7968
# Epoch 33/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4227 - accuracy: 0.7994
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4231 - accuracy: 0.7996
# Epoch 34/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4253 - accuracy: 0.7976
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4231 - accuracy: 0.7991
# Epoch 35/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4259 - accuracy: 0.7988
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4259 - accuracy: 0.7989
# Epoch 36/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4393 - accuracy: 0.7837
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 376/376 [==============================] - 0s 749us/step - loss: 0.4473 - accuracy: 0.7740
# Epoch 37/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4803 - accuracy: 0.7685
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4782 - accuracy: 0.7697
# Epoch 38/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4378 - accuracy: 0.7942
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 376/376 [==============================] - 0s 733us/step - loss: 0.4361 - accuracy: 0.7954
# Epoch 39/100
# 360/376 [===========================>..] - ETA: 0s - loss: 0.4249 - accuracy: 0.7993
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 376/376 [==============================] - 0s 737us/step - loss: 0.4253 - accuracy: 0.7989
# Epoch 40/100
# 360/376 [===========================>..] - ETA: 0s - loss: 0.4251 - accuracy: 0.7974
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4238 - accuracy: 0.7984
# Epoch 41/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4222 - accuracy: 0.8008
# Epoch 41: saving model to checkpoints\weights.41.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4230 - accuracy: 0.8004
# Epoch 42/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4463 - accuracy: 0.7885
# Epoch 42: saving model to checkpoints\weights.42.hdf5
# 376/376 [==============================] - 0s 741us/step - loss: 0.4449 - accuracy: 0.7888
# Epoch 43/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4228 - accuracy: 0.7999
# Epoch 43: saving model to checkpoints\weights.43.hdf5
# 376/376 [==============================] - 0s 741us/step - loss: 0.4233 - accuracy: 0.8002
# Epoch 44/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4225 - accuracy: 0.8009
# Epoch 44: saving model to checkpoints\weights.44.hdf5
# 376/376 [==============================] - 0s 753us/step - loss: 0.4230 - accuracy: 0.8001
# Epoch 45/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4245 - accuracy: 0.7985
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4232 - accuracy: 0.7994
# Epoch 46/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4359 - accuracy: 0.7926
# Epoch 46: saving model to checkpoints\weights.46.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4352 - accuracy: 0.7933
# Epoch 47/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4197 - accuracy: 0.8018
# Epoch 47: saving model to checkpoints\weights.47.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4236 - accuracy: 0.7990
# Epoch 48/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4239 - accuracy: 0.7999
# Epoch 48: saving model to checkpoints\weights.48.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4229 - accuracy: 0.8003
# Epoch 49/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4579 - accuracy: 0.7753
# Epoch 49: saving model to checkpoints\weights.49.hdf5
# 376/376 [==============================] - 0s 730us/step - loss: 0.4580 - accuracy: 0.7754
# Epoch 50/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4241 - accuracy: 0.7992
# Epoch 50: saving model to checkpoints\weights.50.hdf5
# 376/376 [==============================] - 0s 737us/step - loss: 0.4240 - accuracy: 0.7989
# Epoch 51/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4228 - accuracy: 0.7997
# Epoch 51: saving model to checkpoints\weights.51.hdf5
# 376/376 [==============================] - 0s 732us/step - loss: 0.4232 - accuracy: 0.7991
# Epoch 52/100
# 368/376 [============================>.] - ETA: 0s - loss: 0.4242 - accuracy: 0.8000
# Epoch 52: saving model to checkpoints\weights.52.hdf5
# 376/376 [==============================] - 0s 723us/step - loss: 0.4244 - accuracy: 0.7997
# Epoch 53/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4246 - accuracy: 0.7977
# Epoch 53: saving model to checkpoints\weights.53.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4233 - accuracy: 0.7991
# Epoch 54/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4724 - accuracy: 0.7697
# Epoch 54: saving model to checkpoints\weights.54.hdf5
# 376/376 [==============================] - 0s 737us/step - loss: 0.4718 - accuracy: 0.7697
# Epoch 55/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4235 - accuracy: 0.8009
# Epoch 55: saving model to checkpoints\weights.55.hdf5
# 376/376 [==============================] - 0s 733us/step - loss: 0.4242 - accuracy: 0.8002
# Epoch 56/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4227 - accuracy: 0.7996
# Epoch 56: saving model to checkpoints\weights.56.hdf5
# 376/376 [==============================] - 0s 748us/step - loss: 0.4230 - accuracy: 0.7997
# Epoch 57/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4228 - accuracy: 0.7997
# Epoch 57: saving model to checkpoints\weights.57.hdf5
# 376/376 [==============================] - 0s 753us/step - loss: 0.4237 - accuracy: 0.7992
# Epoch 58/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4231 - accuracy: 0.8004
# Epoch 58: saving model to checkpoints\weights.58.hdf5
# 376/376 [==============================] - 0s 743us/step - loss: 0.4236 - accuracy: 0.8006
# Epoch 59/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4234 - accuracy: 0.7996
# Epoch 59: saving model to checkpoints\weights.59.hdf5
# 376/376 [==============================] - 0s 745us/step - loss: 0.4232 - accuracy: 0.7999
# Epoch 60/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4220 - accuracy: 0.8003
# Epoch 60: saving model to checkpoints\weights.60.hdf5
# 376/376 [==============================] - 0s 744us/step - loss: 0.4223 - accuracy: 0.7997
# Epoch 61/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4257 - accuracy: 0.7986
# Epoch 61: saving model to checkpoints\weights.61.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4246 - accuracy: 0.7999
# Epoch 62/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4235 - accuracy: 0.8009
# Epoch 62: saving model to checkpoints\weights.62.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4232 - accuracy: 0.8011
# Epoch 63/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4238 - accuracy: 0.7982
# Epoch 63: saving model to checkpoints\weights.63.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4232 - accuracy: 0.7992
# Epoch 64/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4210 - accuracy: 0.8007
# Epoch 64: saving model to checkpoints\weights.64.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4229 - accuracy: 0.7997
# Epoch 65/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4236 - accuracy: 0.8002
# Epoch 65: saving model to checkpoints\weights.65.hdf5
# 376/376 [==============================] - 0s 743us/step - loss: 0.4232 - accuracy: 0.8004
# Epoch 66/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4256 - accuracy: 0.7988
# Epoch 66: saving model to checkpoints\weights.66.hdf5
# 376/376 [==============================] - 0s 723us/step - loss: 0.4256 - accuracy: 0.7990
# Epoch 67/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4272 - accuracy: 0.7992
# Epoch 67: saving model to checkpoints\weights.67.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4286 - accuracy: 0.7985
# Epoch 68/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4231 - accuracy: 0.7987
# Epoch 68: saving model to checkpoints\weights.68.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4228 - accuracy: 0.7992
# Epoch 69/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4227 - accuracy: 0.7997
# Epoch 69: saving model to checkpoints\weights.69.hdf5
# 376/376 [==============================] - 0s 741us/step - loss: 0.4230 - accuracy: 0.8000
# Epoch 70/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4983 - accuracy: 0.7339
# Epoch 70: saving model to checkpoints\weights.70.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4967 - accuracy: 0.7353
# Epoch 71/100
# 349/376 [==========================>...] - ETA: 0s - loss: 0.4293 - accuracy: 0.7945
# Epoch 71: saving model to checkpoints\weights.71.hdf5
# 376/376 [==============================] - 0s 759us/step - loss: 0.4281 - accuracy: 0.7957
# Epoch 72/100
# 351/376 [===========================>..] - ETA: 0s - loss: 0.4266 - accuracy: 0.7961
# Epoch 72: saving model to checkpoints\weights.72.hdf5
# 376/376 [==============================] - 0s 760us/step - loss: 0.4260 - accuracy: 0.7969
# Epoch 73/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4249 - accuracy: 0.7979
# Epoch 73: saving model to checkpoints\weights.73.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4248 - accuracy: 0.7977
# Epoch 74/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4247 - accuracy: 0.7989
# Epoch 74: saving model to checkpoints\weights.74.hdf5
# 376/376 [==============================] - 0s 749us/step - loss: 0.4243 - accuracy: 0.7987
# Epoch 75/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4232 - accuracy: 0.7991
# Epoch 75: saving model to checkpoints\weights.75.hdf5
# 376/376 [==============================] - 0s 740us/step - loss: 0.4233 - accuracy: 0.7990
# Epoch 76/100
# 369/376 [============================>.] - ETA: 0s - loss: 0.4231 - accuracy: 0.7984
# Epoch 76: saving model to checkpoints\weights.76.hdf5
# 376/376 [==============================] - 0s 723us/step - loss: 0.4228 - accuracy: 0.7986
# Epoch 77/100
# 365/376 [============================>.] - ETA: 0s - loss: 0.4220 - accuracy: 0.7989
# Epoch 77: saving model to checkpoints\weights.77.hdf5
# 376/376 [==============================] - 0s 730us/step - loss: 0.4224 - accuracy: 0.7989
# Epoch 78/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4241 - accuracy: 0.7994
# Epoch 78: saving model to checkpoints\weights.78.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4244 - accuracy: 0.7992
# Epoch 79/100
# 359/376 [===========================>..] - ETA: 0s - loss: 0.4247 - accuracy: 0.7984
# Epoch 79: saving model to checkpoints\weights.79.hdf5
# 376/376 [==============================] - 0s 748us/step - loss: 0.4234 - accuracy: 0.7995
# Epoch 80/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4230 - accuracy: 0.7983
# Epoch 80: saving model to checkpoints\weights.80.hdf5
# 376/376 [==============================] - 0s 732us/step - loss: 0.4237 - accuracy: 0.7984
# Epoch 81/100
# 369/376 [============================>.] - ETA: 0s - loss: 0.4213 - accuracy: 0.7982
# Epoch 81: saving model to checkpoints\weights.81.hdf5
# 376/376 [==============================] - 0s 720us/step - loss: 0.4219 - accuracy: 0.7982
# Epoch 82/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4233 - accuracy: 0.7993
# Epoch 82: saving model to checkpoints\weights.82.hdf5
# 376/376 [==============================] - 0s 752us/step - loss: 0.4222 - accuracy: 0.7997
# Epoch 83/100
# 344/376 [==========================>...] - ETA: 0s - loss: 0.4222 - accuracy: 0.7999
# Epoch 83: saving model to checkpoints\weights.83.hdf5
# 376/376 [==============================] - 0s 773us/step - loss: 0.4227 - accuracy: 0.7992
# Epoch 84/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4234 - accuracy: 0.7990
# Epoch 84: saving model to checkpoints\weights.84.hdf5
# 376/376 [==============================] - 0s 746us/step - loss: 0.4231 - accuracy: 0.7994
# Epoch 85/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4274 - accuracy: 0.7983
# Epoch 85: saving model to checkpoints\weights.85.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4262 - accuracy: 0.7991
# Epoch 86/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4216 - accuracy: 0.7993
# Epoch 86: saving model to checkpoints\weights.86.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4219 - accuracy: 0.7992
# Epoch 87/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4252 - accuracy: 0.7992
# Epoch 87: saving model to checkpoints\weights.87.hdf5
# 376/376 [==============================] - 0s 746us/step - loss: 0.4255 - accuracy: 0.7996
# Epoch 88/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4226 - accuracy: 0.7998
# Epoch 88: saving model to checkpoints\weights.88.hdf5
# 376/376 [==============================] - 0s 737us/step - loss: 0.4223 - accuracy: 0.7997
# Epoch 89/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4247 - accuracy: 0.7990
# Epoch 89: saving model to checkpoints\weights.89.hdf5
# 376/376 [==============================] - 0s 729us/step - loss: 0.4242 - accuracy: 0.7992
# Epoch 90/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4239 - accuracy: 0.7986
# Epoch 90: saving model to checkpoints\weights.90.hdf5
# 376/376 [==============================] - 0s 743us/step - loss: 0.4229 - accuracy: 0.7996
# Epoch 91/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4232 - accuracy: 0.7988
# Epoch 91: saving model to checkpoints\weights.91.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4227 - accuracy: 0.7993
# Epoch 92/100
# 366/376 [============================>.] - ETA: 0s - loss: 0.4209 - accuracy: 0.8016
# Epoch 92: saving model to checkpoints\weights.92.hdf5
# 376/376 [==============================] - 0s 726us/step - loss: 0.4224 - accuracy: 0.8006
# Epoch 93/100
# 359/376 [===========================>..] - ETA: 0s - loss: 0.4261 - accuracy: 0.7982
# Epoch 93: saving model to checkpoints\weights.93.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4261 - accuracy: 0.7980
# Epoch 94/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4226 - accuracy: 0.7999
# Epoch 94: saving model to checkpoints\weights.94.hdf5
# 376/376 [==============================] - 0s 742us/step - loss: 0.4233 - accuracy: 0.7997
# Epoch 95/100
# 365/376 [============================>.] - ETA: 0s - loss: 0.4216 - accuracy: 0.8008
# Epoch 95: saving model to checkpoints\weights.95.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4227 - accuracy: 0.8001
# Epoch 96/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4226 - accuracy: 0.7990
# Epoch 96: saving model to checkpoints\weights.96.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4221 - accuracy: 0.7993
# Epoch 97/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4552 - accuracy: 0.7860
# Epoch 97: saving model to checkpoints\weights.97.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4525 - accuracy: 0.7878
# Epoch 98/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4245 - accuracy: 0.7983
# Epoch 98: saving model to checkpoints\weights.98.hdf5
# 376/376 [==============================] - 0s 749us/step - loss: 0.4249 - accuracy: 0.7989
# Epoch 99/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4256 - accuracy: 0.7990
# Epoch 99: saving model to checkpoints\weights.99.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4252 - accuracy: 0.7991
# Epoch 100/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4233 - accuracy: 0.7984
# Epoch 100: saving model to checkpoints\weights.100.hdf5
# 376/376 [==============================] - 0s 723us/step - loss: 0.4225 - accuracy: 0.7992

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# output when neurons at: 300, 150, 20 = 79% (relu)
# output when neurons at: 30, 15, 2 = 79% (relu)
# output when neurons at: 30, 15, 2 = 80% (tanh)
# output when neurons at: 30, 15, 2 = 80.1% (elu)
# output when neurons at: 30, 15, 2 = 80.1% (hard_sigmoid)
# output when neurons at: 30, 15, 2 = 80.28% (hard_sigmoid, elu, elu, hard_sigmoid)
# Out:
# 126/126 - 0s - loss: 0.4327 - accuracy: 0.8004 - 155ms/epoch - 1ms/step
# Loss: 0.43272215127944946, Accuracy: 0.8003991842269897

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")

# %% [markdown]
# # Neural Network Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the csv.
# # b1 view
# df = pd.read_csv("..\ML_Data_&_Preprocessing\b1_df.csv", index_col=[0])
# df.head()


# b2 view
df = pd.read_csv("..\ML_Data_&_Preprocessing\b2_df.csv", index_col=[0])
df.head()

# # b3 view
# df = pd.read_csv("..\ML_Data_&_Preprocessing\b3_df.csv", index_col=[0])
# df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7128/2568660741.py in <module>
#      13
#      14 # b2 view
# ---> 15 df = pd.read_csv("..\ML_Data_&_Preprocessing\b2_df.csv", index_col=[0])
#      16 df.head()
#      17
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# OSError: [Errno 22] Invalid argument: '..\\ML_Data_&_Preprocessing\x082_df.csv'

# %%
df['leads'].value_counts()
# output shows we need to beat an accuracy score of .55 or higher
# Out:
# 1    9568
# 0    6464
# Name: leads, dtype: int64

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = df['leads'].values
X = df.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have X amount of columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 30
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 15
# layer 3 = hidden layer
layer3= 2

nn = tf.keras.models.Sequential()

### Activation functions
# https://www.tensorflow.org/api_docs/python/tf/keras/activations
    
# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="hard_sigmoid")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="elu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='elu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="hard_sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_97 (Dense)            (None, 30)                120
#
#  dense_98 (Dense)            (None, 15)                465
#
#  dense_99 (Dense)            (None, 2)                 32
#
#  dense_100 (Dense)           (None, 1)                 3
#
# =================================================================
# Total params: 620
# Trainable params: 620
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.5716 - accuracy: 0.7284
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 376/376 [==============================] - 1s 707us/step - loss: 0.5723 - accuracy: 0.7291
# Epoch 2/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.5447 - accuracy: 0.7699
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 376/376 [==============================] - 0s 721us/step - loss: 0.5463 - accuracy: 0.7691
# Epoch 3/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.5260 - accuracy: 0.7738
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 376/376 [==============================] - 0s 720us/step - loss: 0.5267 - accuracy: 0.7741
# Epoch 4/100
# 360/376 [===========================>..] - ETA: 0s - loss: 0.5213 - accuracy: 0.7729
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.5197 - accuracy: 0.7742
# Epoch 5/100
# 370/376 [============================>.] - ETA: 0s - loss: 0.5088 - accuracy: 0.7736
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 376/376 [==============================] - 0s 716us/step - loss: 0.5088 - accuracy: 0.7733
# Epoch 6/100
# 373/376 [============================>.] - ETA: 0s - loss: 0.5012 - accuracy: 0.7749
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 376/376 [==============================] - 0s 710us/step - loss: 0.5013 - accuracy: 0.7747
# Epoch 7/100
# 370/376 [============================>.] - ETA: 0s - loss: 0.4972 - accuracy: 0.7749
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 376/376 [==============================] - 0s 715us/step - loss: 0.4965 - accuracy: 0.7752
# Epoch 8/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4943 - accuracy: 0.7760
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 376/376 [==============================] - 0s 710us/step - loss: 0.4940 - accuracy: 0.7762
# Epoch 9/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4919 - accuracy: 0.7762
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 376/376 [==============================] - 0s 715us/step - loss: 0.4915 - accuracy: 0.7764
# Epoch 10/100
# 303/376 [=======================>......] - ETA: 0s - loss: 0.4879 - accuracy: 0.7762
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 376/376 [==============================] - 0s 699us/step - loss: 0.4894 - accuracy: 0.7751
# Epoch 11/100
# 366/376 [============================>.] - ETA: 0s - loss: 0.4888 - accuracy: 0.7782
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 376/376 [==============================] - 0s 723us/step - loss: 0.4875 - accuracy: 0.7782
# Epoch 12/100
# 375/376 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.7792
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 376/376 [==============================] - 0s 707us/step - loss: 0.4854 - accuracy: 0.7789
# Epoch 13/100
# 302/376 [=======================>......] - ETA: 0s - loss: 0.4927 - accuracy: 0.7717
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 376/376 [==============================] - 0s 696us/step - loss: 0.4845 - accuracy: 0.7774
# Epoch 14/100
# 302/376 [=======================>......] - ETA: 0s - loss: 0.4840 - accuracy: 0.7777
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 376/376 [==============================] - 0s 704us/step - loss: 0.4814 - accuracy: 0.7790
# Epoch 15/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4795 - accuracy: 0.7771
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4798 - accuracy: 0.7766
# Epoch 16/100
# 375/376 [============================>.] - ETA: 0s - loss: 0.4776 - accuracy: 0.7790
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 376/376 [==============================] - 0s 707us/step - loss: 0.4777 - accuracy: 0.7789
# Epoch 17/100
# 375/376 [============================>.] - ETA: 0s - loss: 0.4786 - accuracy: 0.7773
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 376/376 [==============================] - 0s 704us/step - loss: 0.4784 - accuracy: 0.7774
# Epoch 18/100
# 303/376 [=======================>......] - ETA: 0s - loss: 0.4729 - accuracy: 0.7800
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 376/376 [==============================] - 0s 696us/step - loss: 0.4758 - accuracy: 0.7784
# Epoch 19/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4747 - accuracy: 0.7777
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 376/376 [==============================] - 0s 723us/step - loss: 0.4740 - accuracy: 0.7778
# Epoch 20/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4746 - accuracy: 0.7775
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4739 - accuracy: 0.7780
# Epoch 21/100
# 360/376 [===========================>..] - ETA: 0s - loss: 0.4700 - accuracy: 0.7782
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4706 - accuracy: 0.7783
# Epoch 22/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4686 - accuracy: 0.7785
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4690 - accuracy: 0.7780
# Epoch 23/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4686 - accuracy: 0.7762
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4672 - accuracy: 0.7772
# Epoch 24/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4700 - accuracy: 0.7776
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4694 - accuracy: 0.7782
# Epoch 25/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4669 - accuracy: 0.7776
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4667 - accuracy: 0.7778
# Epoch 26/100
# 365/376 [============================>.] - ETA: 0s - loss: 0.4652 - accuracy: 0.7773
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4644 - accuracy: 0.7781
# Epoch 27/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4628 - accuracy: 0.7784
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4635 - accuracy: 0.7779
# Epoch 28/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.4640 - accuracy: 0.7771
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 376/376 [==============================] - 0s 710us/step - loss: 0.4639 - accuracy: 0.7772
# Epoch 29/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4637 - accuracy: 0.7794
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4651 - accuracy: 0.7784
# Epoch 30/100
# 373/376 [============================>.] - ETA: 0s - loss: 0.4624 - accuracy: 0.7787
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4632 - accuracy: 0.7779
# Epoch 31/100
# 376/376 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7766
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 376/376 [==============================] - 0s 701us/step - loss: 0.4621 - accuracy: 0.7766
# Epoch 32/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.4649 - accuracy: 0.7767
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 376/376 [==============================] - 0s 707us/step - loss: 0.4645 - accuracy: 0.7768
# Epoch 33/100
# 370/376 [============================>.] - ETA: 0s - loss: 0.4622 - accuracy: 0.7769
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 376/376 [==============================] - 0s 720us/step - loss: 0.4626 - accuracy: 0.7764
# Epoch 34/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4617 - accuracy: 0.7765
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4614 - accuracy: 0.7766
# Epoch 35/100
# 368/376 [============================>.] - ETA: 0s - loss: 0.4609 - accuracy: 0.7777
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 376/376 [==============================] - 0s 716us/step - loss: 0.4623 - accuracy: 0.7773
# Epoch 36/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4650 - accuracy: 0.7771
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 376/376 [==============================] - 0s 749us/step - loss: 0.4650 - accuracy: 0.7770
# Epoch 37/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4612 - accuracy: 0.7767
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 376/376 [==============================] - 0s 737us/step - loss: 0.4613 - accuracy: 0.7771
# Epoch 38/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4598 - accuracy: 0.7765
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4599 - accuracy: 0.7774
# Epoch 39/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4617 - accuracy: 0.7769
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4600 - accuracy: 0.7778
# Epoch 40/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4616 - accuracy: 0.7767
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 376/376 [==============================] - 0s 720us/step - loss: 0.4637 - accuracy: 0.7756
# Epoch 41/100
# 368/376 [============================>.] - ETA: 0s - loss: 0.4677 - accuracy: 0.7767
# Epoch 41: saving model to checkpoints\weights.41.hdf5
# 376/376 [==============================] - 0s 718us/step - loss: 0.4678 - accuracy: 0.7769
# Epoch 42/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4619 - accuracy: 0.7760
# Epoch 42: saving model to checkpoints\weights.42.hdf5
# 376/376 [==============================] - 0s 711us/step - loss: 0.4616 - accuracy: 0.7759
# Epoch 43/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4591 - accuracy: 0.7772
# Epoch 43: saving model to checkpoints\weights.43.hdf5
# 376/376 [==============================] - 0s 711us/step - loss: 0.4595 - accuracy: 0.7769
# Epoch 44/100
# 370/376 [============================>.] - ETA: 0s - loss: 0.4576 - accuracy: 0.7780
# Epoch 44: saving model to checkpoints\weights.44.hdf5
# 376/376 [==============================] - 0s 715us/step - loss: 0.4577 - accuracy: 0.7778
# Epoch 45/100
# 370/376 [============================>.] - ETA: 0s - loss: 0.4629 - accuracy: 0.7779
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 376/376 [==============================] - 0s 715us/step - loss: 0.4628 - accuracy: 0.7776
# Epoch 46/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4574 - accuracy: 0.7773
# Epoch 46: saving model to checkpoints\weights.46.hdf5
# 376/376 [==============================] - 0s 711us/step - loss: 0.4576 - accuracy: 0.7774
# Epoch 47/100
# 369/376 [============================>.] - ETA: 0s - loss: 0.4593 - accuracy: 0.7778
# Epoch 47: saving model to checkpoints\weights.47.hdf5
# 376/376 [==============================] - 0s 720us/step - loss: 0.4598 - accuracy: 0.7779
# Epoch 48/100
# 368/376 [============================>.] - ETA: 0s - loss: 0.4586 - accuracy: 0.7766
# Epoch 48: saving model to checkpoints\weights.48.hdf5
# 376/376 [==============================] - 0s 718us/step - loss: 0.4588 - accuracy: 0.7767
# Epoch 49/100
# 370/376 [============================>.] - ETA: 0s - loss: 0.4643 - accuracy: 0.7773
# Epoch 49: saving model to checkpoints\weights.49.hdf5
# 376/376 [==============================] - 0s 714us/step - loss: 0.4639 - accuracy: 0.7770
# Epoch 50/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.4582 - accuracy: 0.7782
# Epoch 50: saving model to checkpoints\weights.50.hdf5
# 376/376 [==============================] - 0s 707us/step - loss: 0.4581 - accuracy: 0.7783
# Epoch 51/100
# 370/376 [============================>.] - ETA: 0s - loss: 0.4600 - accuracy: 0.7781
# Epoch 51: saving model to checkpoints\weights.51.hdf5
# 376/376 [==============================] - 0s 715us/step - loss: 0.4599 - accuracy: 0.7777
# Epoch 52/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4570 - accuracy: 0.7789
# Epoch 52: saving model to checkpoints\weights.52.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4572 - accuracy: 0.7780
# Epoch 53/100
# 375/376 [============================>.] - ETA: 0s - loss: 0.4581 - accuracy: 0.7772
# Epoch 53: saving model to checkpoints\weights.53.hdf5
# 376/376 [==============================] - 0s 710us/step - loss: 0.4582 - accuracy: 0.7771
# Epoch 54/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4619 - accuracy: 0.7791
# Epoch 54: saving model to checkpoints\weights.54.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4611 - accuracy: 0.7795
# Epoch 55/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4610 - accuracy: 0.7772
# Epoch 55: saving model to checkpoints\weights.55.hdf5
# 376/376 [==============================] - 0s 731us/step - loss: 0.4600 - accuracy: 0.7784
# Epoch 56/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4582 - accuracy: 0.7778
# Epoch 56: saving model to checkpoints\weights.56.hdf5
# 376/376 [==============================] - 0s 711us/step - loss: 0.4582 - accuracy: 0.7779
# Epoch 57/100
# 359/376 [===========================>..] - ETA: 0s - loss: 0.4582 - accuracy: 0.7778
# Epoch 57: saving model to checkpoints\weights.57.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4573 - accuracy: 0.7779
# Epoch 58/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4583 - accuracy: 0.7770
# Epoch 58: saving model to checkpoints\weights.58.hdf5
# 376/376 [==============================] - 0s 751us/step - loss: 0.4572 - accuracy: 0.7785
# Epoch 59/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4562 - accuracy: 0.7807
# Epoch 59: saving model to checkpoints\weights.59.hdf5
# 376/376 [==============================] - 0s 720us/step - loss: 0.4578 - accuracy: 0.7797
# Epoch 60/100
# 362/376 [===========================>..] - ETA: 0s - loss: 0.4586 - accuracy: 0.7792
# Epoch 60: saving model to checkpoints\weights.60.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4585 - accuracy: 0.7787
# Epoch 61/100
# 368/376 [============================>.] - ETA: 0s - loss: 0.4587 - accuracy: 0.7791
# Epoch 61: saving model to checkpoints\weights.61.hdf5
# 376/376 [==============================] - 0s 720us/step - loss: 0.4587 - accuracy: 0.7791
# Epoch 62/100
# 360/376 [===========================>..] - ETA: 0s - loss: 0.4577 - accuracy: 0.7786
# Epoch 62: saving model to checkpoints\weights.62.hdf5
# 376/376 [==============================] - 0s 734us/step - loss: 0.4592 - accuracy: 0.7784
# Epoch 63/100
# 370/376 [============================>.] - ETA: 0s - loss: 0.4592 - accuracy: 0.7788
# Epoch 63: saving model to checkpoints\weights.63.hdf5
# 376/376 [==============================] - 0s 717us/step - loss: 0.4591 - accuracy: 0.7787
# Epoch 64/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4577 - accuracy: 0.7772
# Epoch 64: saving model to checkpoints\weights.64.hdf5
# 376/376 [==============================] - 0s 720us/step - loss: 0.4584 - accuracy: 0.7771
# Epoch 65/100
# 375/376 [============================>.] - ETA: 0s - loss: 0.4675 - accuracy: 0.7742
# Epoch 65: saving model to checkpoints\weights.65.hdf5
# 376/376 [==============================] - 0s 706us/step - loss: 0.4673 - accuracy: 0.7743
# Epoch 66/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4593 - accuracy: 0.7802
# Epoch 66: saving model to checkpoints\weights.66.hdf5
# 376/376 [==============================] - 0s 713us/step - loss: 0.4602 - accuracy: 0.7792
# Epoch 67/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4566 - accuracy: 0.7788
# Epoch 67: saving model to checkpoints\weights.67.hdf5
# 376/376 [==============================] - 0s 710us/step - loss: 0.4570 - accuracy: 0.7790
# Epoch 68/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.4563 - accuracy: 0.7791
# Epoch 68: saving model to checkpoints\weights.68.hdf5
# 376/376 [==============================] - 0s 706us/step - loss: 0.4565 - accuracy: 0.7788
# Epoch 69/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4585 - accuracy: 0.7791
# Epoch 69: saving model to checkpoints\weights.69.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4576 - accuracy: 0.7794
# Epoch 70/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4591 - accuracy: 0.7783
# Epoch 70: saving model to checkpoints\weights.70.hdf5
# 376/376 [==============================] - 0s 713us/step - loss: 0.4588 - accuracy: 0.7787
# Epoch 71/100
# 369/376 [============================>.] - ETA: 0s - loss: 0.4564 - accuracy: 0.7790
# Epoch 71: saving model to checkpoints\weights.71.hdf5
# 376/376 [==============================] - 0s 715us/step - loss: 0.4585 - accuracy: 0.7782
# Epoch 72/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4592 - accuracy: 0.7788
# Epoch 72: saving model to checkpoints\weights.72.hdf5
# 376/376 [==============================] - 0s 713us/step - loss: 0.4587 - accuracy: 0.7788
# Epoch 73/100
# 373/376 [============================>.] - ETA: 0s - loss: 0.4568 - accuracy: 0.7776
# Epoch 73: saving model to checkpoints\weights.73.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4569 - accuracy: 0.7776
# Epoch 74/100
# 375/376 [============================>.] - ETA: 0s - loss: 0.4577 - accuracy: 0.7793
# Epoch 74: saving model to checkpoints\weights.74.hdf5
# 376/376 [==============================] - 0s 705us/step - loss: 0.4576 - accuracy: 0.7793
# Epoch 75/100
# 373/376 [============================>.] - ETA: 0s - loss: 0.4581 - accuracy: 0.7779
# Epoch 75: saving model to checkpoints\weights.75.hdf5
# 376/376 [==============================] - 0s 709us/step - loss: 0.4573 - accuracy: 0.7783
# Epoch 76/100
# 373/376 [============================>.] - ETA: 0s - loss: 0.4573 - accuracy: 0.7782
# Epoch 76: saving model to checkpoints\weights.76.hdf5
# 376/376 [==============================] - 0s 710us/step - loss: 0.4578 - accuracy: 0.7779
# Epoch 77/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4592 - accuracy: 0.7784
# Epoch 77: saving model to checkpoints\weights.77.hdf5
# 376/376 [==============================] - 0s 711us/step - loss: 0.4593 - accuracy: 0.7783
# Epoch 78/100
# 367/376 [============================>.] - ETA: 0s - loss: 0.4578 - accuracy: 0.7787
# Epoch 78: saving model to checkpoints\weights.78.hdf5
# 376/376 [==============================] - 0s 719us/step - loss: 0.4582 - accuracy: 0.7787
# Epoch 79/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.4819 - accuracy: 0.7739
# Epoch 79: saving model to checkpoints\weights.79.hdf5
# 376/376 [==============================] - 0s 710us/step - loss: 0.4817 - accuracy: 0.7740
# Epoch 80/100
# 368/376 [============================>.] - ETA: 0s - loss: 0.4565 - accuracy: 0.7802
# Epoch 80: saving model to checkpoints\weights.80.hdf5
# 376/376 [==============================] - 0s 723us/step - loss: 0.4579 - accuracy: 0.7794
# Epoch 81/100
# 369/376 [============================>.] - ETA: 0s - loss: 0.4567 - accuracy: 0.7793
# Epoch 81: saving model to checkpoints\weights.81.hdf5
# 376/376 [==============================] - 0s 716us/step - loss: 0.4562 - accuracy: 0.7798
# Epoch 82/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4569 - accuracy: 0.7786
# Epoch 82: saving model to checkpoints\weights.82.hdf5
# 376/376 [==============================] - 0s 709us/step - loss: 0.4564 - accuracy: 0.7788
# Epoch 83/100
# 376/376 [==============================] - ETA: 0s - loss: 0.4564 - accuracy: 0.7792
# Epoch 83: saving model to checkpoints\weights.83.hdf5
# 376/376 [==============================] - 0s 702us/step - loss: 0.4564 - accuracy: 0.7792
# Epoch 84/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.4578 - accuracy: 0.7782
# Epoch 84: saving model to checkpoints\weights.84.hdf5
# 376/376 [==============================] - 0s 710us/step - loss: 0.4575 - accuracy: 0.7784
# Epoch 85/100
# 373/376 [============================>.] - ETA: 0s - loss: 0.4623 - accuracy: 0.7776
# Epoch 85: saving model to checkpoints\weights.85.hdf5
# 376/376 [==============================] - 0s 711us/step - loss: 0.4619 - accuracy: 0.7779
# Epoch 86/100
# 366/376 [============================>.] - ETA: 0s - loss: 0.4580 - accuracy: 0.7780
# Epoch 86: saving model to checkpoints\weights.86.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4572 - accuracy: 0.7785
# Epoch 87/100
# 310/376 [=======================>......] - ETA: 0s - loss: 0.4552 - accuracy: 0.7782
# Epoch 87: saving model to checkpoints\weights.87.hdf5
# 376/376 [==============================] - 0s 683us/step - loss: 0.4569 - accuracy: 0.7781
# Epoch 88/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4563 - accuracy: 0.7792
# Epoch 88: saving model to checkpoints\weights.88.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4561 - accuracy: 0.7796
# Epoch 89/100
# 304/376 [=======================>......] - ETA: 0s - loss: 0.4579 - accuracy: 0.7780
# Epoch 89: saving model to checkpoints\weights.89.hdf5
# 376/376 [==============================] - 0s 699us/step - loss: 0.4563 - accuracy: 0.7783
# Epoch 90/100
# 304/376 [=======================>......] - ETA: 0s - loss: 0.4600 - accuracy: 0.7779
# Epoch 90: saving model to checkpoints\weights.90.hdf5
# 376/376 [==============================] - 0s 694us/step - loss: 0.4582 - accuracy: 0.7793
# Epoch 91/100
# 307/376 [=======================>......] - ETA: 0s - loss: 0.4596 - accuracy: 0.7776
# Epoch 91: saving model to checkpoints\weights.91.hdf5
# 376/376 [==============================] - 0s 688us/step - loss: 0.4572 - accuracy: 0.7779
# Epoch 92/100
# 303/376 [=======================>......] - ETA: 0s - loss: 0.4596 - accuracy: 0.7775
# Epoch 92: saving model to checkpoints\weights.92.hdf5
# 376/376 [==============================] - 0s 696us/step - loss: 0.4568 - accuracy: 0.7798
# Epoch 93/100
# 305/376 [=======================>......] - ETA: 0s - loss: 0.4588 - accuracy: 0.7795
# Epoch 93: saving model to checkpoints\weights.93.hdf5
# 376/376 [==============================] - 0s 694us/step - loss: 0.4594 - accuracy: 0.7779
# Epoch 94/100
# 307/376 [=======================>......] - ETA: 0s - loss: 0.4600 - accuracy: 0.7783
# Epoch 94: saving model to checkpoints\weights.94.hdf5
# 376/376 [==============================] - 0s 686us/step - loss: 0.4567 - accuracy: 0.7789
# Epoch 95/100
# 306/376 [=======================>......] - ETA: 0s - loss: 0.4585 - accuracy: 0.7791
# Epoch 95: saving model to checkpoints\weights.95.hdf5
# 376/376 [==============================] - 0s 696us/step - loss: 0.4573 - accuracy: 0.7793
# Epoch 96/100
# 306/376 [=======================>......] - ETA: 0s - loss: 0.4564 - accuracy: 0.7811
# Epoch 96: saving model to checkpoints\weights.96.hdf5
# 376/376 [==============================] - 0s 691us/step - loss: 0.4588 - accuracy: 0.7803
# Epoch 97/100
# 372/376 [============================>.] - ETA: 0s - loss: 0.4564 - accuracy: 0.7786
# Epoch 97: saving model to checkpoints\weights.97.hdf5
# 376/376 [==============================] - 0s 712us/step - loss: 0.4569 - accuracy: 0.7787
# Epoch 98/100
# 310/376 [=======================>......] - ETA: 0s - loss: 0.4603 - accuracy: 0.7765
# Epoch 98: saving model to checkpoints\weights.98.hdf5
# 376/376 [==============================] - 0s 688us/step - loss: 0.4573 - accuracy: 0.7790
# Epoch 99/100
# 304/376 [=======================>......] - ETA: 0s - loss: 0.4566 - accuracy: 0.7812
# Epoch 99: saving model to checkpoints\weights.99.hdf5
# 376/376 [==============================] - 0s 694us/step - loss: 0.4580 - accuracy: 0.7789
# Epoch 100/100
# 303/376 [=======================>......] - ETA: 0s - loss: 0.4566 - accuracy: 0.7801
# Epoch 100: saving model to checkpoints\weights.100.hdf5
# 376/376 [==============================] - 0s 699us/step - loss: 0.4600 - accuracy: 0.7789

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# output when neurons at: 300, 150, 20 = 79% (relu)
# output when neurons at: 30, 15, 2 = 79% (relu)
# output when neurons at: 30, 15, 2 = 80% (tanh)
# output when neurons at: 30, 15, 2 = 80.1% (elu)
# output when neurons at: 30, 15, 2 = 80.1% (hard_sigmoid)
# output when neurons at: 30, 15, 2 = 80.28% (hard_sigmoid, elu, elu, hard_sigmoid)
# Out:
# 126/126 - 0s - loss: 0.4764 - accuracy: 0.7794 - 135ms/epoch - 1ms/step
# Loss: 0.47642064094543457, Accuracy: 0.7794411182403564

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")

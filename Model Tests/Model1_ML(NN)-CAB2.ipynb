# %% [markdown]
# # Neural Network Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the csv.
# # b1 view
# df = pd.read_csv("..\ML_Data_&_Preprocessing\b1_df.csv", index_col=[0])
# df.head()


# b2 view
df = pd.read_csv("../ML_Data_&_Preprocessing/ca_b2_df.csv", index_col=[0])
df.head()

# # b3 view
# df = pd.read_csv("..\ML_Data_&_Preprocessing\b3_df.csv", index_col=[0])
# df.head()
# Out:
#    spend  Impressions  leads  link_clicks  reach  Agency Tiers
# 0  40.27         1397      1           17   1320             4
# 1  50.27         2969      1           24   2766             4
# 2  63.96         3025      1           10   2818             4
# 3  88.15         4732      1           38   4497             4
# 4  54.42         1981      1           19   1792             4

# %%
df['leads'].value_counts()
# output shows we need to beat an accuracy score of .55 or higher
# Out:
# 1    9568
# 0    6464
# Name: leads, dtype: int64

# %%
# drop reach column here

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = df['leads'].values
X = df.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have X amount of columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 30
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 15
# layer 3 = hidden layer
layer3= 2

nn = tf.keras.models.Sequential()

### Activation functions
# https://www.tensorflow.org/api_docs/python/tf/keras/activations
    
# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="hard_sigmoid")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="elu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='elu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="hard_sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                180
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 2)                 32
#
#  dense_3 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 680
# Trainable params: 680
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.5374 - accuracy: 0.7339
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 376/376 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7342
# Epoch 2/100
# 336/376 [=========================>....] - ETA: 0s - loss: 0.4623 - accuracy: 0.7881
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 376/376 [==============================] - 0s 931us/step - loss: 0.4617 - accuracy: 0.7900
# Epoch 3/100
# 334/376 [=========================>....] - ETA: 0s - loss: 0.4556 - accuracy: 0.7901
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 376/376 [==============================] - 0s 939us/step - loss: 0.4553 - accuracy: 0.7905
# Epoch 4/100
# 336/376 [=========================>....] - ETA: 0s - loss: 0.4447 - accuracy: 0.7965
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 376/376 [==============================] - 0s 777us/step - loss: 0.4462 - accuracy: 0.7953
# Epoch 5/100
# 337/376 [=========================>....] - ETA: 0s - loss: 0.4455 - accuracy: 0.7941
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 376/376 [==============================] - 0s 916us/step - loss: 0.4426 - accuracy: 0.7953
# Epoch 6/100
# 352/376 [===========================>..] - ETA: 0s - loss: 0.4402 - accuracy: 0.7978
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 376/376 [==============================] - 0s 1ms/step - loss: 0.4401 - accuracy: 0.7974
# Epoch 7/100
# 354/376 [===========================>..] - ETA: 0s - loss: 0.4481 - accuracy: 0.7907
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 376/376 [==============================] - 0s 915us/step - loss: 0.4480 - accuracy: 0.7899
# Epoch 8/100
# 313/376 [=======================>......] - ETA: 0s - loss: 0.4341 - accuracy: 0.7980
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 376/376 [==============================] - 0s 837us/step - loss: 0.4342 - accuracy: 0.7978
# Epoch 9/100
# 315/376 [========================>.....] - ETA: 0s - loss: 0.4340 - accuracy: 0.7994
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 376/376 [==============================] - 0s 832us/step - loss: 0.4320 - accuracy: 0.7999
# Epoch 10/100
# 346/376 [==========================>...] - ETA: 0s - loss: 0.4338 - accuracy: 0.7967
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 376/376 [==============================] - 0s 765us/step - loss: 0.4321 - accuracy: 0.7985
# Epoch 11/100
# 321/376 [========================>.....] - ETA: 0s - loss: 0.4329 - accuracy: 0.7993
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 376/376 [==============================] - 0s 835us/step - loss: 0.4315 - accuracy: 0.8002
# Epoch 12/100
# 376/376 [==============================] - ETA: 0s - loss: 0.4305 - accuracy: 0.7992
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 376/376 [==============================] - 0s 995us/step - loss: 0.4305 - accuracy: 0.7992
# Epoch 13/100
# 340/376 [==========================>...] - ETA: 0s - loss: 0.4363 - accuracy: 0.8003
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 376/376 [==============================] - 0s 773us/step - loss: 0.4329 - accuracy: 0.8016
# Epoch 14/100
# 325/376 [========================>.....] - ETA: 0s - loss: 0.4390 - accuracy: 0.7962
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 376/376 [==============================] - 0s 799us/step - loss: 0.4393 - accuracy: 0.7950
# Epoch 15/100
# 368/376 [============================>.] - ETA: 0s - loss: 0.4278 - accuracy: 0.7997
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 376/376 [==============================] - 0s 859us/step - loss: 0.4277 - accuracy: 0.7993
# Epoch 16/100
# 329/376 [=========================>....] - ETA: 0s - loss: 0.4303 - accuracy: 0.8015
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 376/376 [==============================] - 0s 804us/step - loss: 0.4308 - accuracy: 0.8021
# Epoch 17/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4290 - accuracy: 0.8013
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 376/376 [==============================] - 0s 756us/step - loss: 0.4291 - accuracy: 0.8003
# Epoch 18/100
# 350/376 [==========================>...] - ETA: 0s - loss: 0.4446 - accuracy: 0.7918
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 376/376 [==============================] - 0s 751us/step - loss: 0.4456 - accuracy: 0.7932
# Epoch 19/100
# 354/376 [===========================>..] - ETA: 0s - loss: 0.4545 - accuracy: 0.7904
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 376/376 [==============================] - 0s 754us/step - loss: 0.4541 - accuracy: 0.7914
# Epoch 20/100
# 349/376 [==========================>...] - ETA: 0s - loss: 0.4387 - accuracy: 0.7966
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 376/376 [==============================] - 0s 766us/step - loss: 0.4378 - accuracy: 0.7973
# Epoch 21/100
# 334/376 [=========================>....] - ETA: 0s - loss: 0.4300 - accuracy: 0.7995
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 376/376 [==============================] - 0s 805us/step - loss: 0.4307 - accuracy: 0.7996
# Epoch 22/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4288 - accuracy: 0.8011
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 376/376 [==============================] - 0s 861us/step - loss: 0.4288 - accuracy: 0.8008
# Epoch 23/100
# 327/376 [=========================>....] - ETA: 0s - loss: 0.4438 - accuracy: 0.7927
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 376/376 [==============================] - 0s 797us/step - loss: 0.4425 - accuracy: 0.7935
# Epoch 24/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4282 - accuracy: 0.7998
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 376/376 [==============================] - 0s 749us/step - loss: 0.4294 - accuracy: 0.7991
# Epoch 25/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4264 - accuracy: 0.8032
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 376/376 [==============================] - 0s 749us/step - loss: 0.4284 - accuracy: 0.8014
# Epoch 26/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4287 - accuracy: 0.8005
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4283 - accuracy: 0.8015
# Epoch 27/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4301 - accuracy: 0.7984
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 376/376 [==============================] - 0s 738us/step - loss: 0.4279 - accuracy: 0.8008
# Epoch 28/100
# 317/376 [========================>.....] - ETA: 0s - loss: 0.4309 - accuracy: 0.7998
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 376/376 [==============================] - 0s 809us/step - loss: 0.4292 - accuracy: 0.8017
# Epoch 29/100
# 356/376 [===========================>..] - ETA: 0s - loss: 0.4301 - accuracy: 0.8031
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4314 - accuracy: 0.8020
# Epoch 30/100
# 348/376 [==========================>...] - ETA: 0s - loss: 0.4382 - accuracy: 0.7954
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 376/376 [==============================] - 0s 757us/step - loss: 0.4359 - accuracy: 0.7961
# Epoch 31/100
# 346/376 [==========================>...] - ETA: 0s - loss: 0.4259 - accuracy: 0.8016
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 376/376 [==============================] - 0s 782us/step - loss: 0.4270 - accuracy: 0.8012
# Epoch 32/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4273 - accuracy: 0.8019
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 376/376 [==============================] - 0s 753us/step - loss: 0.4274 - accuracy: 0.8026
# Epoch 33/100
# 349/376 [==========================>...] - ETA: 0s - loss: 0.4288 - accuracy: 0.7975
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 376/376 [==============================] - 0s 773us/step - loss: 0.4274 - accuracy: 0.7992
# Epoch 34/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4296 - accuracy: 0.7993
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4404 - accuracy: 0.7899
# Epoch 35/100
# 364/376 [============================>.] - ETA: 0s - loss: 0.4523 - accuracy: 0.7903
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 376/376 [==============================] - 0s 727us/step - loss: 0.4515 - accuracy: 0.7913
# Epoch 36/100
# 363/376 [===========================>..] - ETA: 0s - loss: 0.4298 - accuracy: 0.7988
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 376/376 [==============================] - 0s 728us/step - loss: 0.4294 - accuracy: 0.7989
# Epoch 37/100
# 359/376 [===========================>..] - ETA: 0s - loss: 0.4273 - accuracy: 0.7993
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 376/376 [==============================] - 0s 741us/step - loss: 0.4270 - accuracy: 0.7997
# Epoch 38/100
# 349/376 [==========================>...] - ETA: 0s - loss: 0.4289 - accuracy: 0.8012
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 376/376 [==============================] - 0s 752us/step - loss: 0.4285 - accuracy: 0.8010
# Epoch 39/100
# 352/376 [===========================>..] - ETA: 0s - loss: 0.4235 - accuracy: 0.8023
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 376/376 [==============================] - 0s 744us/step - loss: 0.4256 - accuracy: 0.8008
# Epoch 40/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4274 - accuracy: 0.8019
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4275 - accuracy: 0.8026
# Epoch 41/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4277 - accuracy: 0.7984
# Epoch 41: saving model to checkpoints\weights.41.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4261 - accuracy: 0.7988
# Epoch 42/100
# 354/376 [===========================>..] - ETA: 0s - loss: 0.4682 - accuracy: 0.7644
# Epoch 42: saving model to checkpoints\weights.42.hdf5
# 376/376 [==============================] - 0s 749us/step - loss: 0.4717 - accuracy: 0.7644
# Epoch 43/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4788 - accuracy: 0.7807
# Epoch 43: saving model to checkpoints\weights.43.hdf5
# 376/376 [==============================] - 0s 749us/step - loss: 0.4772 - accuracy: 0.7807
# Epoch 44/100
# 359/376 [===========================>..] - ETA: 0s - loss: 0.4437 - accuracy: 0.7920
# Epoch 44: saving model to checkpoints\weights.44.hdf5
# 376/376 [==============================] - 0s 737us/step - loss: 0.4448 - accuracy: 0.7913
# Epoch 45/100
# 358/376 [===========================>..] - ETA: 0s - loss: 0.4396 - accuracy: 0.7947
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 376/376 [==============================] - 0s 736us/step - loss: 0.4375 - accuracy: 0.7963
# Epoch 46/100
# 360/376 [===========================>..] - ETA: 0s - loss: 0.4346 - accuracy: 0.8009
# Epoch 46: saving model to checkpoints\weights.46.hdf5
# 376/376 [==============================] - 0s 739us/step - loss: 0.4352 - accuracy: 0.7993
# Epoch 47/100
# 351/376 [===========================>..] - ETA: 0s - loss: 0.4330 - accuracy: 0.7985
# Epoch 47: saving model to checkpoints\weights.47.hdf5
# 376/376 [==============================] - 0s 765us/step - loss: 0.4344 - accuracy: 0.7987
# Epoch 48/100
# 343/376 [==========================>...] - ETA: 0s - loss: 0.4343 - accuracy: 0.7988
# Epoch 48: saving model to checkpoints\weights.48.hdf5
# 376/376 [==============================] - 0s 759us/step - loss: 0.4333 - accuracy: 0.7992
# Epoch 49/100
# 349/376 [==========================>...] - ETA: 0s - loss: 0.4340 - accuracy: 0.7967
# Epoch 49: saving model to checkpoints\weights.49.hdf5
# 376/376 [==============================] - 0s 763us/step - loss: 0.4333 - accuracy: 0.7972
# Epoch 50/100
# 340/376 [==========================>...] - ETA: 0s - loss: 0.4319 - accuracy: 0.8004
# Epoch 50: saving model to checkpoints\weights.50.hdf5
# 376/376 [==============================] - 0s 770us/step - loss: 0.4301 - accuracy: 0.8011
# Epoch 51/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4255 - accuracy: 0.8022
# Epoch 51: saving model to checkpoints\weights.51.hdf5
# 376/376 [==============================] - 0s 737us/step - loss: 0.4271 - accuracy: 0.8011
# Epoch 52/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4258 - accuracy: 0.8019
# Epoch 52: saving model to checkpoints\weights.52.hdf5
# 376/376 [==============================] - 0s 747us/step - loss: 0.4264 - accuracy: 0.8005
# Epoch 53/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4263 - accuracy: 0.8004
# Epoch 53: saving model to checkpoints\weights.53.hdf5
# 376/376 [==============================] - 0s 744us/step - loss: 0.4257 - accuracy: 0.8007
# Epoch 54/100
# 361/376 [===========================>..] - ETA: 0s - loss: 0.4241 - accuracy: 0.8025
# Epoch 54: saving model to checkpoints\weights.54.hdf5
# 376/376 [==============================] - 0s 867us/step - loss: 0.4252 - accuracy: 0.8012
# Epoch 55/100
# 340/376 [==========================>...] - ETA: 0s - loss: 0.4248 - accuracy: 0.8012
# Epoch 55: saving model to checkpoints\weights.55.hdf5
# 376/376 [==============================] - 0s 771us/step - loss: 0.4266 - accuracy: 0.8003
# Epoch 56/100
# 338/376 [=========================>....] - ETA: 0s - loss: 0.4306 - accuracy: 0.7989
# Epoch 56: saving model to checkpoints\weights.56.hdf5
# 376/376 [==============================] - 0s 781us/step - loss: 0.4294 - accuracy: 0.7988
# Epoch 57/100
# 318/376 [========================>.....] - ETA: 0s - loss: 0.4302 - accuracy: 0.7961
# Epoch 57: saving model to checkpoints\weights.57.hdf5
# 376/376 [==============================] - 0s 827us/step - loss: 0.4269 - accuracy: 0.7986
# Epoch 58/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.4254 - accuracy: 0.8006
# Epoch 58: saving model to checkpoints\weights.58.hdf5
# 376/376 [==============================] - 0s 848us/step - loss: 0.4251 - accuracy: 0.8006
# Epoch 59/100
# 342/376 [==========================>...] - ETA: 0s - loss: 0.4261 - accuracy: 0.8005
# Epoch 59: saving model to checkpoints\weights.59.hdf5
# 376/376 [==============================] - 0s 909us/step - loss: 0.4259 - accuracy: 0.8001
# Epoch 60/100
# 349/376 [==========================>...] - ETA: 0s - loss: 0.4265 - accuracy: 0.8006
# Epoch 60: saving model to checkpoints\weights.60.hdf5
# 376/376 [==============================] - 0s 1ms/step - loss: 0.4244 - accuracy: 0.8017
# Epoch 61/100
# 312/376 [=======================>......] - ETA: 0s - loss: 0.4312 - accuracy: 0.8020
# Epoch 61: saving model to checkpoints\weights.61.hdf5
# 376/376 [==============================] - 0s 835us/step - loss: 0.4284 - accuracy: 0.8031
# Epoch 62/100
# 329/376 [=========================>....] - ETA: 0s - loss: 0.4272 - accuracy: 0.8014
# Epoch 62: saving model to checkpoints\weights.62.hdf5
# 376/376 [==============================] - 0s 795us/step - loss: 0.4267 - accuracy: 0.8014
# Epoch 63/100
# 336/376 [=========================>....] - ETA: 0s - loss: 0.4258 - accuracy: 0.8038
# Epoch 63: saving model to checkpoints\weights.63.hdf5
# 376/376 [==============================] - 0s 784us/step - loss: 0.4408 - accuracy: 0.7949
# Epoch 64/100
# 343/376 [==========================>...] - ETA: 0s - loss: 0.4642 - accuracy: 0.7855
# Epoch 64: saving model to checkpoints\weights.64.hdf5
# 376/376 [==============================] - 0s 771us/step - loss: 0.4604 - accuracy: 0.7883
# Epoch 65/100
# 330/376 [=========================>....] - ETA: 0s - loss: 0.4447 - accuracy: 0.7937
# Epoch 65: saving model to checkpoints\weights.65.hdf5
# 376/376 [==============================] - 0s 808us/step - loss: 0.4440 - accuracy: 0.7937
# Epoch 66/100
# 324/376 [========================>.....] - ETA: 0s - loss: 0.4396 - accuracy: 0.7950
# Epoch 66: saving model to checkpoints\weights.66.hdf5
# 376/376 [==============================] - 0s 811us/step - loss: 0.4405 - accuracy: 0.7942
# Epoch 67/100
# 375/376 [============================>.] - ETA: 0s - loss: 0.4381 - accuracy: 0.7960
# Epoch 67: saving model to checkpoints\weights.67.hdf5
# 376/376 [==============================] - 0s 845us/step - loss: 0.4378 - accuracy: 0.7962
# Epoch 68/100
# 318/376 [========================>.....] - ETA: 0s - loss: 0.4337 - accuracy: 0.7967
# Epoch 68: saving model to checkpoints\weights.68.hdf5
# 376/376 [==============================] - 0s 825us/step - loss: 0.4343 - accuracy: 0.7971
# Epoch 69/100
# 327/376 [=========================>....] - ETA: 0s - loss: 0.4271 - accuracy: 0.7991
# Epoch 69: saving model to checkpoints\weights.69.hdf5
# 376/376 [==============================] - 0s 829us/step - loss: 0.4272 - accuracy: 0.7993
# Epoch 70/100
# 347/376 [==========================>...] - ETA: 0s - loss: 0.4220 - accuracy: 0.8030
# Epoch 70: saving model to checkpoints\weights.70.hdf5
# 376/376 [==============================] - 0s 984us/step - loss: 0.4243 - accuracy: 0.8009
# Epoch 71/100
# 333/376 [=========================>....] - ETA: 0s - loss: 0.4299 - accuracy: 0.8006
# Epoch 71: saving model to checkpoints\weights.71.hdf5
# 376/376 [==============================] - 0s 1ms/step - loss: 0.4266 - accuracy: 0.8017
# Epoch 72/100
# 355/376 [===========================>..] - ETA: 0s - loss: 0.4248 - accuracy: 0.8007
# Epoch 72: saving model to checkpoints\weights.72.hdf5
# 376/376 [==============================] - 0s 891us/step - loss: 0.4249 - accuracy: 0.8012
# Epoch 73/100
# 345/376 [==========================>...] - ETA: 0s - loss: 0.4262 - accuracy: 0.8015
# Epoch 73: saving model to checkpoints\weights.73.hdf5
# 376/376 [==============================] - 0s 915us/step - loss: 0.4263 - accuracy: 0.8020
# Epoch 74/100
# 366/376 [============================>.] - ETA: 0s - loss: 0.4257 - accuracy: 0.8026
# Epoch 74: saving model to checkpoints\weights.74.hdf5
# 376/376 [==============================] - 0s 872us/step - loss: 0.4259 - accuracy: 0.8020
# Epoch 75/100
# 374/376 [============================>.] - ETA: 0s - loss: 0.4241 - accuracy: 0.7993
# Epoch 75: saving model to checkpoints\weights.75.hdf5
# 376/376 [==============================] - 0s 843us/step - loss: 0.4242 - accuracy: 0.7993
# Epoch 76/100
# 336/376 [=========================>....] - ETA: 0s - loss: 0.4267 - accuracy: 0.8002
# Epoch 76: saving model to checkpoints\weights.76.hdf5
# 376/376 [==============================] - 0s 792us/step - loss: 0.4249 - accuracy: 0.8012
# Epoch 77/100
# 332/376 [=========================>....] - ETA: 0s - loss: 0.4232 - accuracy: 0.8017
# Epoch 77: saving model to checkpoints\weights.77.hdf5
# 376/376 [==============================] - 0s 784us/step - loss: 0.4242 - accuracy: 0.8016
# Epoch 78/100
# 328/376 [=========================>....] - ETA: 0s - loss: 0.4242 - accuracy: 0.8037
# Epoch 78: saving model to checkpoints\weights.78.hdf5
# 376/376 [==============================] - 0s 808us/step - loss: 0.4252 - accuracy: 0.8026
# Epoch 79/100
# 353/376 [===========================>..] - ETA: 0s - loss: 0.4275 - accuracy: 0.8027
# Epoch 79: saving model to checkpoints\weights.79.hdf5
# 376/376 [==============================] - 0s 899us/step - loss: 0.4271 - accuracy: 0.8034
# Epoch 80/100
# 330/376 [=========================>....] - ETA: 0s - loss: 0.4260 - accuracy: 0.8029
# Epoch 80: saving model to checkpoints\weights.80.hdf5
# 376/376 [==============================] - 0s 813us/step - loss: 0.4249 - accuracy: 0.8034
# Epoch 81/100
# 314/376 [========================>.....] - ETA: 0s - loss: 0.4209 - accuracy: 0.8012
# Epoch 81: saving model to checkpoints\weights.81.hdf5
# 376/376 [==============================] - 0s 832us/step - loss: 0.4251 - accuracy: 0.7989
# Epoch 82/100
# 332/376 [=========================>....] - ETA: 0s - loss: 0.4240 - accuracy: 0.8035
# Epoch 82: saving model to checkpoints\weights.82.hdf5
# 376/376 [==============================] - 0s 794us/step - loss: 0.4255 - accuracy: 0.8024
# Epoch 83/100
# 313/376 [=======================>......] - ETA: 0s - loss: 0.4209 - accuracy: 0.7998
# Epoch 83: saving model to checkpoints\weights.83.hdf5
# 376/376 [==============================] - 0s 828us/step - loss: 0.4218 - accuracy: 0.7997
# Epoch 84/100
# 322/376 [========================>.....] - ETA: 0s - loss: 0.4212 - accuracy: 0.8022
# Epoch 84: saving model to checkpoints\weights.84.hdf5
# 376/376 [==============================] - 0s 819us/step - loss: 0.4240 - accuracy: 0.8006
# Epoch 85/100
# 357/376 [===========================>..] - ETA: 0s - loss: 0.4246 - accuracy: 0.8019
# Epoch 85: saving model to checkpoints\weights.85.hdf5
# 376/376 [==============================] - 0s 875us/step - loss: 0.4245 - accuracy: 0.8020
# Epoch 86/100
# 321/376 [========================>.....] - ETA: 0s - loss: 0.4177 - accuracy: 0.8026
# Epoch 86: saving model to checkpoints\weights.86.hdf5
# 376/376 [==============================] - 0s 816us/step - loss: 0.4216 - accuracy: 0.8006
# Epoch 87/100
# 328/376 [=========================>....] - ETA: 0s - loss: 0.4267 - accuracy: 0.7992
# Epoch 87: saving model to checkpoints\weights.87.hdf5
# 376/376 [==============================] - 0s 800us/step - loss: 0.4259 - accuracy: 0.8004
# Epoch 88/100
# 323/376 [========================>.....] - ETA: 0s - loss: 0.4200 - accuracy: 0.8006
# Epoch 88: saving model to checkpoints\weights.88.hdf5
# 376/376 [==============================] - 0s 816us/step - loss: 0.4218 - accuracy: 0.8007
# Epoch 89/100
# 371/376 [============================>.] - ETA: 0s - loss: 0.4240 - accuracy: 0.8032
# Epoch 89: saving model to checkpoints\weights.89.hdf5
# 376/376 [==============================] - 0s 853us/step - loss: 0.4236 - accuracy: 0.8040
# Epoch 90/100
# 319/376 [========================>.....] - ETA: 0s - loss: 0.4217 - accuracy: 0.8026
# Epoch 90: saving model to checkpoints\weights.90.hdf5
# 376/376 [==============================] - 0s 840us/step - loss: 0.4223 - accuracy: 0.8020
# Epoch 91/100
# 335/376 [=========================>....] - ETA: 0s - loss: 0.4198 - accuracy: 0.8034
# Epoch 91: saving model to checkpoints\weights.91.hdf5
# 376/376 [==============================] - 0s 955us/step - loss: 0.4212 - accuracy: 0.8019
# Epoch 92/100
# 317/376 [========================>.....] - ETA: 0s - loss: 0.4228 - accuracy: 0.8030
# Epoch 92: saving model to checkpoints\weights.92.hdf5
# 376/376 [==============================] - 0s 971us/step - loss: 0.4212 - accuracy: 0.8021
# Epoch 93/100
# 318/376 [========================>.....] - ETA: 0s - loss: 0.4206 - accuracy: 0.8002
# Epoch 93: saving model to checkpoints\weights.93.hdf5
# 376/376 [==============================] - 0s 957us/step - loss: 0.4227 - accuracy: 0.8007
# Epoch 94/100
# 324/376 [========================>.....] - ETA: 0s - loss: 0.4241 - accuracy: 0.8017
# Epoch 94: saving model to checkpoints\weights.94.hdf5
# 376/376 [==============================] - 0s 805us/step - loss: 0.4244 - accuracy: 0.8016
# Epoch 95/100
# 328/376 [=========================>....] - ETA: 0s - loss: 0.4276 - accuracy: 0.7992
# Epoch 95: saving model to checkpoints\weights.95.hdf5
# 376/376 [==============================] - 0s 805us/step - loss: 0.4253 - accuracy: 0.8012
# Epoch 96/100
# 326/376 [=========================>....] - ETA: 0s - loss: 0.4219 - accuracy: 0.8028
# Epoch 96: saving model to checkpoints\weights.96.hdf5
# 376/376 [==============================] - 0s 811us/step - loss: 0.4212 - accuracy: 0.8022
# Epoch 97/100
# 373/376 [============================>.] - ETA: 0s - loss: 0.4193 - accuracy: 0.8029
# Epoch 97: saving model to checkpoints\weights.97.hdf5
# 376/376 [==============================] - 0s 843us/step - loss: 0.4191 - accuracy: 0.8027
# Epoch 98/100
# 328/376 [=========================>....] - ETA: 0s - loss: 0.4254 - accuracy: 0.7989
# Epoch 98: saving model to checkpoints\weights.98.hdf5
# 376/376 [==============================] - 0s 803us/step - loss: 0.4220 - accuracy: 0.8017
# Epoch 99/100
# 332/376 [=========================>....] - ETA: 0s - loss: 0.4197 - accuracy: 0.8012
# Epoch 99: saving model to checkpoints\weights.99.hdf5
# 376/376 [==============================] - 0s 797us/step - loss: 0.4204 - accuracy: 0.8006
# Epoch 100/100
# 373/376 [============================>.] - ETA: 0s - loss: 0.4379 - accuracy: 0.7948
# Epoch 100: saving model to checkpoints\weights.100.hdf5
# 376/376 [==============================] - 0s 845us/step - loss: 0.4374 - accuracy: 0.7952

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# output when neurons at: 300, 150, 20 = 79% (relu)
# output when neurons at: 30, 15, 2 = 79% (relu)
# output when neurons at: 30, 15, 2 = 80% (tanh)
# output when neurons at: 30, 15, 2 = 80.1% (elu)
# output when neurons at: 30, 15, 2 = 80.1% (hard_sigmoid)
# output when neurons at: 30, 15, 2 = 80.28% (hard_sigmoid, elu, elu, hard_sigmoid)
# Out:
# 126/126 - 0s - loss: 0.4321 - accuracy: 0.7884 - 168ms/epoch - 1ms/step
# Loss: 0.43209943175315857, Accuracy: 0.7884231805801392

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")

# %% [markdown]
# # Neural Network Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the csv.
# b1 view
df = pd.read_csv("../ML_Data_&_Preprocessing/b1_df_nonEncoded.csv", index_col=[0])
df.head()

# # b2 view
# df = pd.read_csv("../ML_Data_&_Preprocessing/b2_df_nonEncoded.csv", index_col=[0])
# df.head()

# # b3 view
# df = pd.read_csv("../ML_Data_&_Preprocessing/b3_df_nonEncoded.csv", index_col=[0])
# df.head()
# Out:
#   state  spend  Impressions  leads  link_clicks  reach  Agency Tiers
# 0    TN   8.96          492      0            0    483           NaN
# 1    GA  15.92          797      0            3    773           NaN
# 2    MO  11.16          836      1            2    798           NaN
# 3    RI   8.80          759      0            2    729           NaN
# 4    CA   5.83          500      0            0    476           NaN

# %%
df['leads'].value_counts()
# Out:
# 0    57153
# 1    45676
# Name: leads, dtype: int64

# %%
# check on different state values for testing 
df['state'].value_counts()
# Out:
# TX    12200
# CA     9216
# OH     7480
# TN     5689
# FL     4675
# CO     4518
# IL     4425
# PA     4360
# MO     4318
# NJ     3974
# NC     3823
# MI     3791
# AZ     3660
# GA     2751
# MN     2409
# WA     2303
# WI     2004
# NY     1978
# OR     1800
# MA     1737
# LA     1603
# CT     1491
# IN     1310
# KY     1242
# VA     1148
# KS     1098
# IA      927
# RI      908
# MS      873
# ME      747
# NM      707
# OK      613
# SC      565
# UT      451
# ID      392
# ND      387
# AR      368
# NV      338
# AL      290
# NE      260
# Name: state, dtype: int64

# %%
df2 = df.loc[df['state']== 'PA']
df2
# Out:
#       state  spend  Impressions  leads  link_clicks  reach  Agency Tiers
# 12       PA  12.73          978      1            2    886           NaN
# 28       PA  25.24         1804      1            4   1662           NaN
# 45       PA  16.97          712      0            1    643           NaN
# 59       PA   9.64          793      0            3    742           NaN
# 69       PA  15.31          989      1            3    928           NaN
# ...     ...    ...          ...    ...          ...    ...           ...
# 88355    PA   0.00            0      0            0      0           NaN
# 88357    PA   6.73          347      0            1    339           NaN
# 88359    PA  14.93          889      1            5    853           NaN
# 88361    PA  15.02          740      1            6    710           NaN
# 88362    PA  10.28          401      0            4    382           NaN
#
# [4360 rows x 7 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4360 entries, 12 to 88362
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         4360 non-null   object
#  1   spend         4360 non-null   float64
#  2   Impressions   4360 non-null   int64
#  3   leads         4360 non-null   int64
#  4   link_clicks   4360 non-null   int64
#  5   reach         4360 non-null   int64
#  6   Agency Tiers  0 non-null      float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 272.5+ KB

# %%
df3 = df2.drop(df2.columns[[0,6]], axis=1)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4360 entries, 12 to 88362
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   spend        4360 non-null   float64
#  1   Impressions  4360 non-null   int64
#  2   leads        4360 non-null   int64
#  3   link_clicks  4360 non-null   int64
#  4   reach        4360 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 204.4 KB

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = df3['leads'].values
X = df3.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have X amount of columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 30
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 15
# layer 3 = hidden layer
layer3= 2

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="hard_sigmoid")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="elu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='elu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="hard_sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                150
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 2)                 32
#
#  dense_3 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 650
# Trainable params: 650
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 103/103 [==============================] - ETA: 0s - loss: 0.6473 - accuracy: 0.6554
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 103/103 [==============================] - 1s 4ms/step - loss: 0.6473 - accuracy: 0.6554
# Epoch 2/100
#  98/103 [===========================>..] - ETA: 0s - loss: 0.5551 - accuracy: 0.7446
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5518 - accuracy: 0.7450
# Epoch 3/100
#  90/103 [=========================>....] - ETA: 0s - loss: 0.5222 - accuracy: 0.7531
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5332 - accuracy: 0.7520
# Epoch 4/100
#  92/103 [=========================>....] - ETA: 0s - loss: 0.5429 - accuracy: 0.7435
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5328 - accuracy: 0.7474
# Epoch 5/100
#  87/103 [========================>.....] - ETA: 0s - loss: 0.5381 - accuracy: 0.7428
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5356 - accuracy: 0.7434
# Epoch 6/100
#  91/103 [=========================>....] - ETA: 0s - loss: 0.5345 - accuracy: 0.7390
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5352 - accuracy: 0.7373
# Epoch 7/100
#  89/103 [========================>.....] - ETA: 0s - loss: 0.5102 - accuracy: 0.7423
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5080 - accuracy: 0.7446
# Epoch 8/100
#  92/103 [=========================>....] - ETA: 0s - loss: 0.5224 - accuracy: 0.7401
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5311 - accuracy: 0.7333
# Epoch 9/100
#  89/103 [========================>.....] - ETA: 0s - loss: 0.5269 - accuracy: 0.7412
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5244 - accuracy: 0.7428
# Epoch 10/100
#  92/103 [=========================>....] - ETA: 0s - loss: 0.5099 - accuracy: 0.7466
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5076 - accuracy: 0.7465
# Epoch 11/100
# 101/103 [============================>.] - ETA: 0s - loss: 0.4967 - accuracy: 0.7485
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4979 - accuracy: 0.7477
# Epoch 12/100
#  95/103 [==========================>...] - ETA: 0s - loss: 0.4973 - accuracy: 0.7510
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7498
# Epoch 13/100
#  91/103 [=========================>....] - ETA: 0s - loss: 0.4938 - accuracy: 0.7527
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.7505
# Epoch 14/100
#  92/103 [=========================>....] - ETA: 0s - loss: 0.4848 - accuracy: 0.7548
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4915 - accuracy: 0.7505
# Epoch 15/100
# 102/103 [============================>.] - ETA: 0s - loss: 0.4886 - accuracy: 0.7540
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4883 - accuracy: 0.7541
# Epoch 16/100
#  88/103 [========================>.....] - ETA: 0s - loss: 0.4821 - accuracy: 0.7582
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4887 - accuracy: 0.7544
# Epoch 17/100
#  95/103 [==========================>...] - ETA: 0s - loss: 0.4898 - accuracy: 0.7487
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4884 - accuracy: 0.7514
# Epoch 18/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4816 - accuracy: 0.7578
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4833 - accuracy: 0.7563
# Epoch 19/100
#  98/103 [===========================>..] - ETA: 0s - loss: 0.4808 - accuracy: 0.7577
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4824 - accuracy: 0.7569
# Epoch 20/100
#  89/103 [========================>.....] - ETA: 0s - loss: 0.4777 - accuracy: 0.7584
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4807 - accuracy: 0.7581
# Epoch 21/100
#  98/103 [===========================>..] - ETA: 0s - loss: 0.4811 - accuracy: 0.7577
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.4799 - accuracy: 0.7581
# Epoch 22/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4779 - accuracy: 0.7594
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4783 - accuracy: 0.7593
# Epoch 23/100
#  90/103 [=========================>....] - ETA: 0s - loss: 0.4828 - accuracy: 0.7569
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4778 - accuracy: 0.7584
# Epoch 24/100
# 102/103 [============================>.] - ETA: 0s - loss: 0.4777 - accuracy: 0.7626
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4773 - accuracy: 0.7627
# Epoch 25/100
#  90/103 [=========================>....] - ETA: 0s - loss: 0.4719 - accuracy: 0.7656
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4763 - accuracy: 0.7612
# Epoch 26/100
#  73/103 [====================>.........] - ETA: 0s - loss: 0.4713 - accuracy: 0.7714
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4758 - accuracy: 0.7627
# Epoch 27/100
#  89/103 [========================>.....] - ETA: 0s - loss: 0.4731 - accuracy: 0.7651
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4744 - accuracy: 0.7636
# Epoch 28/100
#  84/103 [=======================>......] - ETA: 0s - loss: 0.4769 - accuracy: 0.7600
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4736 - accuracy: 0.7645
# Epoch 29/100
#  93/103 [==========================>...] - ETA: 0s - loss: 0.4747 - accuracy: 0.7608
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4727 - accuracy: 0.7633
# Epoch 30/100
#  97/103 [===========================>..] - ETA: 0s - loss: 0.4701 - accuracy: 0.7668
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4716 - accuracy: 0.7654
# Epoch 31/100
#  93/103 [==========================>...] - ETA: 0s - loss: 0.4706 - accuracy: 0.7661
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.4703 - accuracy: 0.7664
# Epoch 32/100
#  97/103 [===========================>..] - ETA: 0s - loss: 0.4669 - accuracy: 0.7706
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.4699 - accuracy: 0.7679
# Epoch 33/100
#  96/103 [==========================>...] - ETA: 0s - loss: 0.4692 - accuracy: 0.7679
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.4695 - accuracy: 0.7661
# Epoch 34/100
#  89/103 [========================>.....] - ETA: 0s - loss: 0.4703 - accuracy: 0.7637
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4691 - accuracy: 0.7661
# Epoch 35/100
#  94/103 [==========================>...] - ETA: 0s - loss: 0.4673 - accuracy: 0.7689
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.4690 - accuracy: 0.7688
# Epoch 36/100
#  93/103 [==========================>...] - ETA: 0s - loss: 0.4708 - accuracy: 0.7675
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4670 - accuracy: 0.7700
# Epoch 37/100
#  94/103 [==========================>...] - ETA: 0s - loss: 0.4707 - accuracy: 0.7626
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 103/103 [==============================] - 0s 4ms/step - loss: 0.4673 - accuracy: 0.7676
# Epoch 38/100
#  80/103 [======================>.......] - ETA: 0s - loss: 0.4608 - accuracy: 0.7750
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.7713
# Epoch 39/100
#  96/103 [==========================>...] - ETA: 0s - loss: 0.4619 - accuracy: 0.7708
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.7697
# Epoch 40/100
#  99/103 [===========================>..] - ETA: 0s - loss: 0.4647 - accuracy: 0.7683
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.4636 - accuracy: 0.7682
# Epoch 41/100
#  83/103 [=======================>......] - ETA: 0s - loss: 0.4652 - accuracy: 0.7722
# Epoch 41: saving model to checkpoints\weights.41.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4672 - accuracy: 0.7725
# Epoch 42/100
#  70/103 [===================>..........] - ETA: 0s - loss: 0.4484 - accuracy: 0.7812
# Epoch 42: saving model to checkpoints\weights.42.hdf5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.4624 - accuracy: 0.7713
# Epoch 43/100
#  95/103 [==========================>...] - ETA: 0s - loss: 0.4608 - accuracy: 0.7681
# Epoch 43: saving model to checkpoints\weights.43.hdf5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.4625 - accuracy: 0.7670
# Epoch 44/100
#  95/103 [==========================>...] - ETA: 0s - loss: 0.4618 - accuracy: 0.7664
# Epoch 44: saving model to checkpoints\weights.44.hdf5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.7651
# Epoch 45/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4608 - accuracy: 0.7713
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4609 - accuracy: 0.7713
# Epoch 46/100
# 101/103 [============================>.] - ETA: 0s - loss: 0.4580 - accuracy: 0.7692
# Epoch 46: saving model to checkpoints\weights.46.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4594 - accuracy: 0.7679
# Epoch 47/100
#  90/103 [=========================>....] - ETA: 0s - loss: 0.4922 - accuracy: 0.7483
# Epoch 47: saving model to checkpoints\weights.47.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4983 - accuracy: 0.7428
# Epoch 48/100
#  97/103 [===========================>..] - ETA: 0s - loss: 0.5323 - accuracy: 0.7297
# Epoch 48: saving model to checkpoints\weights.48.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5281 - accuracy: 0.7339
# Epoch 49/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.5042 - accuracy: 0.7525
# Epoch 49: saving model to checkpoints\weights.49.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7554
# Epoch 50/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4848 - accuracy: 0.7631
# Epoch 50: saving model to checkpoints\weights.50.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4834 - accuracy: 0.7651
# Epoch 51/100
#  86/103 [========================>.....] - ETA: 0s - loss: 0.4681 - accuracy: 0.7703
# Epoch 51: saving model to checkpoints\weights.51.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.7682
# Epoch 52/100
#  94/103 [==========================>...] - ETA: 0s - loss: 0.4675 - accuracy: 0.7703
# Epoch 52: saving model to checkpoints\weights.52.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4651 - accuracy: 0.7725
# Epoch 53/100
#  87/103 [========================>.....] - ETA: 0s - loss: 0.4619 - accuracy: 0.7676
# Epoch 53: saving model to checkpoints\weights.53.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4624 - accuracy: 0.7682
# Epoch 54/100
#  96/103 [==========================>...] - ETA: 0s - loss: 0.4627 - accuracy: 0.7682
# Epoch 54: saving model to checkpoints\weights.54.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4606 - accuracy: 0.7685
# Epoch 55/100
#  91/103 [=========================>....] - ETA: 0s - loss: 0.4621 - accuracy: 0.7682
# Epoch 55: saving model to checkpoints\weights.55.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4596 - accuracy: 0.7691
# Epoch 56/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4588 - accuracy: 0.7700
# Epoch 56: saving model to checkpoints\weights.56.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4593 - accuracy: 0.7697
# Epoch 57/100
#  96/103 [==========================>...] - ETA: 0s - loss: 0.4577 - accuracy: 0.7712
# Epoch 57: saving model to checkpoints\weights.57.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4590 - accuracy: 0.7691
# Epoch 58/100
#  93/103 [==========================>...] - ETA: 0s - loss: 0.4614 - accuracy: 0.7658
# Epoch 58: saving model to checkpoints\weights.58.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4585 - accuracy: 0.7685
# Epoch 59/100
# 102/103 [============================>.] - ETA: 0s - loss: 0.4583 - accuracy: 0.7681
# Epoch 59: saving model to checkpoints\weights.59.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4580 - accuracy: 0.7685
# Epoch 60/100
#  80/103 [======================>.......] - ETA: 0s - loss: 0.4604 - accuracy: 0.7680
# Epoch 60: saving model to checkpoints\weights.60.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4580 - accuracy: 0.7688
# Epoch 61/100
#  87/103 [========================>.....] - ETA: 0s - loss: 0.4619 - accuracy: 0.7680
# Epoch 61: saving model to checkpoints\weights.61.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4574 - accuracy: 0.7703
# Epoch 62/100
#  96/103 [==========================>...] - ETA: 0s - loss: 0.4548 - accuracy: 0.7718
# Epoch 62: saving model to checkpoints\weights.62.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4575 - accuracy: 0.7700
# Epoch 63/100
#  89/103 [========================>.....] - ETA: 0s - loss: 0.4587 - accuracy: 0.7704
# Epoch 63: saving model to checkpoints\weights.63.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4571 - accuracy: 0.7706
# Epoch 64/100
#  93/103 [==========================>...] - ETA: 0s - loss: 0.4570 - accuracy: 0.7688
# Epoch 64: saving model to checkpoints\weights.64.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4566 - accuracy: 0.7713
# Epoch 65/100
#  96/103 [==========================>...] - ETA: 0s - loss: 0.4569 - accuracy: 0.7718
# Epoch 65: saving model to checkpoints\weights.65.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4569 - accuracy: 0.7709
# Epoch 66/100
#  81/103 [======================>.......] - ETA: 0s - loss: 0.4553 - accuracy: 0.7716
# Epoch 66: saving model to checkpoints\weights.66.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4558 - accuracy: 0.7703
# Epoch 67/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4569 - accuracy: 0.7722
# Epoch 67: saving model to checkpoints\weights.67.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4557 - accuracy: 0.7728
# Epoch 68/100
#  82/103 [======================>.......] - ETA: 0s - loss: 0.4592 - accuracy: 0.7717
# Epoch 68: saving model to checkpoints\weights.68.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4558 - accuracy: 0.7749
# Epoch 69/100
#  98/103 [===========================>..] - ETA: 0s - loss: 0.4555 - accuracy: 0.7701
# Epoch 69: saving model to checkpoints\weights.69.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4553 - accuracy: 0.7697
# Epoch 70/100
#  98/103 [===========================>..] - ETA: 0s - loss: 0.4556 - accuracy: 0.7688
# Epoch 70: saving model to checkpoints\weights.70.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4552 - accuracy: 0.7700
# Epoch 71/100
#  96/103 [==========================>...] - ETA: 0s - loss: 0.4557 - accuracy: 0.7712
# Epoch 71: saving model to checkpoints\weights.71.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4556 - accuracy: 0.7706
# Epoch 72/100
#  91/103 [=========================>....] - ETA: 0s - loss: 0.4604 - accuracy: 0.7727
# Epoch 72: saving model to checkpoints\weights.72.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4587 - accuracy: 0.7722
# Epoch 73/100
#  86/103 [========================>.....] - ETA: 0s - loss: 0.4622 - accuracy: 0.7765
# Epoch 73: saving model to checkpoints\weights.73.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4584 - accuracy: 0.7746
# Epoch 74/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4548 - accuracy: 0.7741
# Epoch 74: saving model to checkpoints\weights.74.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4548 - accuracy: 0.7731
# Epoch 75/100
#  93/103 [==========================>...] - ETA: 0s - loss: 0.4554 - accuracy: 0.7725
# Epoch 75: saving model to checkpoints\weights.75.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4539 - accuracy: 0.7731
# Epoch 76/100
#  98/103 [===========================>..] - ETA: 0s - loss: 0.4547 - accuracy: 0.7714
# Epoch 76: saving model to checkpoints\weights.76.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4536 - accuracy: 0.7725
# Epoch 77/100
# 102/103 [============================>.] - ETA: 0s - loss: 0.4603 - accuracy: 0.7705
# Epoch 77: saving model to checkpoints\weights.77.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4598 - accuracy: 0.7706
# Epoch 78/100
#  99/103 [===========================>..] - ETA: 0s - loss: 0.4565 - accuracy: 0.7699
# Epoch 78: saving model to checkpoints\weights.78.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4541 - accuracy: 0.7719
# Epoch 79/100
#  84/103 [=======================>......] - ETA: 0s - loss: 0.4528 - accuracy: 0.7723
# Epoch 79: saving model to checkpoints\weights.79.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4531 - accuracy: 0.7731
# Epoch 80/100
#  98/103 [===========================>..] - ETA: 0s - loss: 0.4646 - accuracy: 0.7736
# Epoch 80: saving model to checkpoints\weights.80.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4651 - accuracy: 0.7749
# Epoch 81/100
#  82/103 [======================>.......] - ETA: 0s - loss: 0.4578 - accuracy: 0.7721
# Epoch 81: saving model to checkpoints\weights.81.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4572 - accuracy: 0.7728
# Epoch 82/100
# 101/103 [============================>.] - ETA: 0s - loss: 0.4554 - accuracy: 0.7704
# Epoch 82: saving model to checkpoints\weights.82.hdf5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.4549 - accuracy: 0.7709
# Epoch 83/100
#  91/103 [=========================>....] - ETA: 0s - loss: 0.4521 - accuracy: 0.7679
# Epoch 83: saving model to checkpoints\weights.83.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4532 - accuracy: 0.7697
# Epoch 84/100
#  87/103 [========================>.....] - ETA: 0s - loss: 0.4596 - accuracy: 0.7647
# Epoch 84: saving model to checkpoints\weights.84.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4526 - accuracy: 0.7719
# Epoch 85/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4559 - accuracy: 0.7706
# Epoch 85: saving model to checkpoints\weights.85.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4534 - accuracy: 0.7728
# Epoch 86/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4534 - accuracy: 0.7716
# Epoch 86: saving model to checkpoints\weights.86.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4525 - accuracy: 0.7722
# Epoch 87/100
#  91/103 [=========================>....] - ETA: 0s - loss: 0.4468 - accuracy: 0.7785
# Epoch 87: saving model to checkpoints\weights.87.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4527 - accuracy: 0.7737
# Epoch 88/100
#  99/103 [===========================>..] - ETA: 0s - loss: 0.4547 - accuracy: 0.7699
# Epoch 88: saving model to checkpoints\weights.88.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4531 - accuracy: 0.7709
# Epoch 89/100
# 103/103 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.7761
# Epoch 89: saving model to checkpoints\weights.89.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4522 - accuracy: 0.7761
# Epoch 90/100
#  96/103 [==========================>...] - ETA: 0s - loss: 0.4505 - accuracy: 0.7712
# Epoch 90: saving model to checkpoints\weights.90.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4526 - accuracy: 0.7709
# Epoch 91/100
#  90/103 [=========================>....] - ETA: 0s - loss: 0.4559 - accuracy: 0.7656
# Epoch 91: saving model to checkpoints\weights.91.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4591 - accuracy: 0.7700
# Epoch 92/100
#  94/103 [==========================>...] - ETA: 0s - loss: 0.4520 - accuracy: 0.7749
# Epoch 92: saving model to checkpoints\weights.92.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4552 - accuracy: 0.7719
# Epoch 93/100
#  97/103 [===========================>..] - ETA: 0s - loss: 0.4528 - accuracy: 0.7709
# Epoch 93: saving model to checkpoints\weights.93.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4513 - accuracy: 0.7725
# Epoch 94/100
#  95/103 [==========================>...] - ETA: 0s - loss: 0.4566 - accuracy: 0.7760
# Epoch 94: saving model to checkpoints\weights.94.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4600 - accuracy: 0.7731
# Epoch 95/100
#  99/103 [===========================>..] - ETA: 0s - loss: 0.4495 - accuracy: 0.7708
# Epoch 95: saving model to checkpoints\weights.95.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4526 - accuracy: 0.7691
# Epoch 96/100
# 103/103 [==============================] - ETA: 0s - loss: 0.4507 - accuracy: 0.7700
# Epoch 96: saving model to checkpoints\weights.96.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4507 - accuracy: 0.7700
# Epoch 97/100
# 100/103 [============================>.] - ETA: 0s - loss: 0.4515 - accuracy: 0.7684
# Epoch 97: saving model to checkpoints\weights.97.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4511 - accuracy: 0.7685
# Epoch 98/100
#  99/103 [===========================>..] - ETA: 0s - loss: 0.4551 - accuracy: 0.7702
# Epoch 98: saving model to checkpoints\weights.98.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4535 - accuracy: 0.7713
# Epoch 99/100
#  97/103 [===========================>..] - ETA: 0s - loss: 0.4553 - accuracy: 0.7671
# Epoch 99: saving model to checkpoints\weights.99.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4533 - accuracy: 0.7700
# Epoch 100/100
# 103/103 [==============================] - ETA: 0s - loss: 0.4538 - accuracy: 0.7706
# Epoch 100: saving model to checkpoints\weights.100.hdf5
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4538 - accuracy: 0.7706

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# when brand 1, all states, accuracy = 36%
# when brand 2, all states, accuracy = 36%
# when brand 3, all states, accuracy = 36%

# B1, CA = 78%
# B2, CA = 80%
# B3, CA = 77%

# B3, PA = 100%
# B3, TX = 76%
# Out:
# 35/35 - 0s - loss: 0.4530 - accuracy: 0.7642 - 232ms/epoch - 7ms/step
# Loss: 0.4530448317527771, Accuracy: 0.7642201781272888

# %% [markdown]
# ### B1 Results

# %%
data_results_b1 = {
        'State': ['CA'],
        'Predictive Accuracy': [.78],
        'Notes': ['N/A']}
data_results_b1
# Out:
# {'State': ['CA'], 'Predictive Accuracy': [0.78], 'Notes': ['N/A']}

# %%
# add more data to b1 data results dict

# %%
# create the new df to display brand, state, and model accuracy 
df_results_b1 = pd.DataFrame(data_results_b1)
df_results_b1
# Out:
#   State  Predictive Accuracy Notes
# 0    CA                 0.78   N/A

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")

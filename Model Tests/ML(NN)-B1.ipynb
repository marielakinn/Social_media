# %% [markdown]
# # Neural Network Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the csv.
# b1 view
df = pd.read_csv("../ML_Data_&_Preprocessing/b1_df_nonEncoded.csv", index_col=[0])
df.head()
# Out:
#   state  spend  Impressions  leads  link_clicks  reach  Agency Tiers
# 0    TN   8.96          492      0            0    483           NaN
# 1    GA  15.92          797      0            3    773           NaN
# 2    MO  11.16          836      1            2    798           NaN
# 3    RI   8.80          759      0            2    729           NaN
# 4    CA   5.83          500      0            0    476           NaN

# %%
df['leads'].value_counts()
# Out:
# 0    57153
# 1    45676
# Name: leads, dtype: int64

# %%
# check on different state values for testing 
df['state'].value_counts()
# Out:
# TX    12200
# CA     9216
# OH     7480
# TN     5689
# FL     4675
# CO     4518
# IL     4425
# PA     4360
# MO     4318
# NJ     3974
# NC     3823
# MI     3791
# AZ     3660
# GA     2751
# MN     2409
# WA     2303
# WI     2004
# NY     1978
# OR     1800
# MA     1737
# LA     1603
# CT     1491
# IN     1310
# KY     1242
# VA     1148
# KS     1098
# IA      927
# RI      908
# MS      873
# ME      747
# NM      707
# OK      613
# SC      565
# UT      451
# ID      392
# ND      387
# AR      368
# NV      338
# AL      290
# NE      260
# Name: state, dtype: int64

# %%
df2 = df.loc[df['state']== 'LA']
df2
# Out:
#       state  spend  Impressions  leads  link_clicks  reach  Agency Tiers
# 73       LA   0.00            0      0            0      0           NaN
# 81       LA  18.14         1013      0            7    931           NaN
# 127      LA  12.10         1225      1            5   1123           NaN
# 199      LA  12.13          543      0            7    511           NaN
# 200      LA   8.08          706      0            3    664           NaN
# ...     ...    ...          ...    ...          ...    ...           ...
# 41989    LA   7.81          695      0            1    656           NaN
# 41997    LA   7.18          564      0            4    545           NaN
# 41998    LA   6.90          533      0            1    513           NaN
# 42008    LA   3.29          284      1            1    281           NaN
# 42009    LA   3.70          308      0            2    303           NaN
#
# [1603 rows x 7 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1603 entries, 73 to 42009
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         1603 non-null   object
#  1   spend         1603 non-null   float64
#  2   Impressions   1603 non-null   int64
#  3   leads         1603 non-null   int64
#  4   link_clicks   1603 non-null   int64
#  5   reach         1603 non-null   int64
#  6   Agency Tiers  0 non-null      float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 100.2+ KB

# %%
df3 = df2.drop(df2.columns[[0,6]], axis=1)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1603 entries, 73 to 42009
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   spend        1603 non-null   float64
#  1   Impressions  1603 non-null   int64
#  2   leads        1603 non-null   int64
#  3   link_clicks  1603 non-null   int64
#  4   reach        1603 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 75.1 KB

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = df3['leads'].values
X = df3.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have X amount of columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 30
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 15
# layer 3 = hidden layer
layer3= 2

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="hard_sigmoid")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="elu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='elu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="hard_sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 30)                150
#
#  dense_29 (Dense)            (None, 15)                465
#
#  dense_30 (Dense)            (None, 2)                 32
#
#  dense_31 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 650
# Trainable params: 650
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
#  1/38 [..............................] - ETA: 10s - loss: 0.7717 - accuracy: 0.4375
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.7020 - accuracy: 0.5391
# Epoch 2/100
#  1/38 [..............................] - ETA: 0s - loss: 0.6623 - accuracy: 0.5625
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6457 - accuracy: 0.6073
# Epoch 3/100
#  1/38 [..............................] - ETA: 0s - loss: 0.7046 - accuracy: 0.5312
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5993 - accuracy: 0.6905
# Epoch 4/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4753 - accuracy: 0.8750
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5427 - accuracy: 0.7155
# Epoch 5/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4929 - accuracy: 0.7500
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4951 - accuracy: 0.7379
# Epoch 6/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5132 - accuracy: 0.6562
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4752 - accuracy: 0.7438
# Epoch 7/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3902 - accuracy: 0.7812
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4661 - accuracy: 0.7479
# Epoch 8/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5736 - accuracy: 0.6250
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4619 - accuracy: 0.7554
# Epoch 9/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4599 - accuracy: 0.7812
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4613 - accuracy: 0.7629
# Epoch 10/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5315 - accuracy: 0.7188
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4578 - accuracy: 0.7646
# Epoch 11/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5480 - accuracy: 0.6250
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4548 - accuracy: 0.7704
# Epoch 12/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4266 - accuracy: 0.7812
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4533 - accuracy: 0.7745
# Epoch 13/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3828 - accuracy: 0.8438
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4529 - accuracy: 0.7696
# Epoch 14/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4697 - accuracy: 0.7188
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4513 - accuracy: 0.7737
# Epoch 15/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4842 - accuracy: 0.7188
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.7737
# Epoch 16/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3840 - accuracy: 0.8438
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.7720
# Epoch 17/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5003 - accuracy: 0.6875
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4475 - accuracy: 0.7671
# Epoch 18/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3711 - accuracy: 0.8125
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.7679
# Epoch 19/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3126 - accuracy: 0.7812
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4484 - accuracy: 0.7679
# Epoch 20/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5589 - accuracy: 0.6562
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4472 - accuracy: 0.7612
# Epoch 21/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5615 - accuracy: 0.7188
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4493 - accuracy: 0.7612
# Epoch 22/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4482 - accuracy: 0.7188
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.7637
# Epoch 23/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4963 - accuracy: 0.7188
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7687
# Epoch 24/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3677 - accuracy: 0.8750
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.7637
# Epoch 25/100
# 19/38 [==============>...............] - ETA: 0s - loss: 0.4471 - accuracy: 0.7747
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4440 - accuracy: 0.7671
# Epoch 26/100
# 37/38 [============================>.] - ETA: 0s - loss: 0.4452 - accuracy: 0.7660
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4472 - accuracy: 0.7629
# Epoch 27/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.4404 - accuracy: 0.7708
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4467 - accuracy: 0.7662
# Epoch 28/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4587 - accuracy: 0.6875
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4442 - accuracy: 0.7662
# Epoch 29/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3715 - accuracy: 0.8125
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4440 - accuracy: 0.7646
# Epoch 30/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4801 - accuracy: 0.6875
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4416 - accuracy: 0.7646
# Epoch 31/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3947 - accuracy: 0.7500
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4439 - accuracy: 0.7587
# Epoch 32/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3372 - accuracy: 0.8438
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4425 - accuracy: 0.7687
# Epoch 33/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4270 - accuracy: 0.7500
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4439 - accuracy: 0.7712
# Epoch 34/100
#  1/38 [..............................] - ETA: 0s - loss: 0.2943 - accuracy: 0.8125
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4452 - accuracy: 0.7729
# Epoch 35/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4198 - accuracy: 0.8125
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4457 - accuracy: 0.7629
# Epoch 36/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4703 - accuracy: 0.6250
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4416 - accuracy: 0.7662
# Epoch 37/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4491 - accuracy: 0.7812
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4419 - accuracy: 0.7671
# Epoch 38/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4593 - accuracy: 0.7188
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4426 - accuracy: 0.7696
# Epoch 39/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4461 - accuracy: 0.7188
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4411 - accuracy: 0.7696
# Epoch 40/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3520 - accuracy: 0.8125
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4425 - accuracy: 0.7679
# Epoch 41/100
#  1/38 [..............................] - ETA: 0s - loss: 0.2973 - accuracy: 0.8750
# Epoch 41: saving model to checkpoints\weights.41.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4420 - accuracy: 0.7654
# Epoch 42/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4443 - accuracy: 0.7500
# Epoch 42: saving model to checkpoints\weights.42.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4416 - accuracy: 0.7654
# Epoch 43/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5345 - accuracy: 0.6250
# Epoch 43: saving model to checkpoints\weights.43.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4423 - accuracy: 0.7654
# Epoch 44/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4664 - accuracy: 0.7812
# Epoch 44: saving model to checkpoints\weights.44.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4417 - accuracy: 0.7696
# Epoch 45/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4875 - accuracy: 0.6562
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4400 - accuracy: 0.7679
# Epoch 46/100
#  1/38 [..............................] - ETA: 0s - loss: 0.6128 - accuracy: 0.7188
# Epoch 46: saving model to checkpoints\weights.46.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4425 - accuracy: 0.7679
# Epoch 47/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4837 - accuracy: 0.7500
# Epoch 47: saving model to checkpoints\weights.47.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4425 - accuracy: 0.7646
# Epoch 48/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4506 - accuracy: 0.7500
# Epoch 48: saving model to checkpoints\weights.48.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4400 - accuracy: 0.7654
# Epoch 49/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3878 - accuracy: 0.8125
# Epoch 49: saving model to checkpoints\weights.49.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4386 - accuracy: 0.7704
# Epoch 50/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4399 - accuracy: 0.7812
# Epoch 50: saving model to checkpoints\weights.50.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4409 - accuracy: 0.7671
# Epoch 51/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3378 - accuracy: 0.8750
# Epoch 51: saving model to checkpoints\weights.51.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4388 - accuracy: 0.7712
# Epoch 52/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4822 - accuracy: 0.7812
# Epoch 52: saving model to checkpoints\weights.52.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4381 - accuracy: 0.7679
# Epoch 53/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4168 - accuracy: 0.7188
# Epoch 53: saving model to checkpoints\weights.53.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4403 - accuracy: 0.7720
# Epoch 54/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4691 - accuracy: 0.7500
# Epoch 54: saving model to checkpoints\weights.54.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4406 - accuracy: 0.7712
# Epoch 55/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4821 - accuracy: 0.7188
# Epoch 55: saving model to checkpoints\weights.55.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4399 - accuracy: 0.7696
# Epoch 56/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3037 - accuracy: 0.9062
# Epoch 56: saving model to checkpoints\weights.56.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4394 - accuracy: 0.7662
# Epoch 57/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4429 - accuracy: 0.8125
# Epoch 57: saving model to checkpoints\weights.57.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4398 - accuracy: 0.7671
# Epoch 58/100
#  1/38 [..............................] - ETA: 0s - loss: 0.6933 - accuracy: 0.6562
# Epoch 58: saving model to checkpoints\weights.58.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4379 - accuracy: 0.7687
# Epoch 59/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4853 - accuracy: 0.6875
# Epoch 59: saving model to checkpoints\weights.59.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4382 - accuracy: 0.7671
# Epoch 60/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4253 - accuracy: 0.7812
# Epoch 60: saving model to checkpoints\weights.60.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4399 - accuracy: 0.7712
# Epoch 61/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3503 - accuracy: 0.8125
# Epoch 61: saving model to checkpoints\weights.61.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4390 - accuracy: 0.7671
# Epoch 62/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4969 - accuracy: 0.6875
# Epoch 62: saving model to checkpoints\weights.62.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4361 - accuracy: 0.7712
# Epoch 63/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4413 - accuracy: 0.7500
# Epoch 63: saving model to checkpoints\weights.63.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4415 - accuracy: 0.7737
# Epoch 64/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4211 - accuracy: 0.8125
# Epoch 64: saving model to checkpoints\weights.64.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4378 - accuracy: 0.7712
# Epoch 65/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4234 - accuracy: 0.8125
# Epoch 65: saving model to checkpoints\weights.65.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4379 - accuracy: 0.7646
# Epoch 66/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4476 - accuracy: 0.7188
# Epoch 66: saving model to checkpoints\weights.66.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4386 - accuracy: 0.7704
# Epoch 67/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5010 - accuracy: 0.6875
# Epoch 67: saving model to checkpoints\weights.67.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4372 - accuracy: 0.7687
# Epoch 68/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3480 - accuracy: 0.7812
# Epoch 68: saving model to checkpoints\weights.68.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4381 - accuracy: 0.7745
# Epoch 69/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5295 - accuracy: 0.7500
# Epoch 69: saving model to checkpoints\weights.69.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4369 - accuracy: 0.7712
# Epoch 70/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3954 - accuracy: 0.8125
# Epoch 70: saving model to checkpoints\weights.70.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4374 - accuracy: 0.7679
# Epoch 71/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4092 - accuracy: 0.7500
# Epoch 71: saving model to checkpoints\weights.71.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4367 - accuracy: 0.7729
# Epoch 72/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3888 - accuracy: 0.7812
# Epoch 72: saving model to checkpoints\weights.72.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4361 - accuracy: 0.7704
# Epoch 73/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3617 - accuracy: 0.8438
# Epoch 73: saving model to checkpoints\weights.73.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4369 - accuracy: 0.7745
# Epoch 74/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4151 - accuracy: 0.8438
# Epoch 74: saving model to checkpoints\weights.74.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4368 - accuracy: 0.7729
# Epoch 75/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5970 - accuracy: 0.6250
# Epoch 75: saving model to checkpoints\weights.75.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4360 - accuracy: 0.7704
# Epoch 76/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3666 - accuracy: 0.8438
# Epoch 76: saving model to checkpoints\weights.76.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4365 - accuracy: 0.7712
# Epoch 77/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4659 - accuracy: 0.7812
# Epoch 77: saving model to checkpoints\weights.77.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4372 - accuracy: 0.7696
# Epoch 78/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4281 - accuracy: 0.7812
# Epoch 78: saving model to checkpoints\weights.78.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4366 - accuracy: 0.7671
# Epoch 79/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3826 - accuracy: 0.7812
# Epoch 79: saving model to checkpoints\weights.79.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4370 - accuracy: 0.7712
# Epoch 80/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3898 - accuracy: 0.7812
# Epoch 80: saving model to checkpoints\weights.80.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4367 - accuracy: 0.7679
# Epoch 81/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4094 - accuracy: 0.8125
# Epoch 81: saving model to checkpoints\weights.81.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4361 - accuracy: 0.7704
# Epoch 82/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3353 - accuracy: 0.8750
# Epoch 82: saving model to checkpoints\weights.82.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4365 - accuracy: 0.7679
# Epoch 83/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3498 - accuracy: 0.8438
# Epoch 83: saving model to checkpoints\weights.83.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4361 - accuracy: 0.7704
# Epoch 84/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3493 - accuracy: 0.8125
# Epoch 84: saving model to checkpoints\weights.84.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4369 - accuracy: 0.7646
# Epoch 85/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3967 - accuracy: 0.8125
# Epoch 85: saving model to checkpoints\weights.85.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4359 - accuracy: 0.7696
# Epoch 86/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5818 - accuracy: 0.6250
# Epoch 86: saving model to checkpoints\weights.86.hdf5
# 38/38 [==============================] - 0s 973us/step - loss: 0.4357 - accuracy: 0.7729
# Epoch 87/100
#  1/38 [..............................] - ETA: 0s - loss: 0.6564 - accuracy: 0.5625
# Epoch 87: saving model to checkpoints\weights.87.hdf5
# 38/38 [==============================] - 0s 919us/step - loss: 0.4350 - accuracy: 0.7712
# Epoch 88/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4905 - accuracy: 0.7500
# Epoch 88: saving model to checkpoints\weights.88.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4354 - accuracy: 0.7696
# Epoch 89/100
#  1/38 [..............................] - ETA: 0s - loss: 0.6149 - accuracy: 0.6875
# Epoch 89: saving model to checkpoints\weights.89.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4350 - accuracy: 0.7737
# Epoch 90/100
#  1/38 [..............................] - ETA: 0s - loss: 0.2987 - accuracy: 0.8750
# Epoch 90: saving model to checkpoints\weights.90.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4350 - accuracy: 0.7704
# Epoch 91/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3515 - accuracy: 0.8750
# Epoch 91: saving model to checkpoints\weights.91.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4356 - accuracy: 0.7720
# Epoch 92/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5608 - accuracy: 0.5938
# Epoch 92: saving model to checkpoints\weights.92.hdf5
# 38/38 [==============================] - 0s 951us/step - loss: 0.4344 - accuracy: 0.7737
# Epoch 93/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4905 - accuracy: 0.8125
# Epoch 93: saving model to checkpoints\weights.93.hdf5
# 38/38 [==============================] - 0s 1000us/step - loss: 0.4347 - accuracy: 0.7712
# Epoch 94/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5244 - accuracy: 0.6875
# Epoch 94: saving model to checkpoints\weights.94.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4365 - accuracy: 0.7662
# Epoch 95/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4541 - accuracy: 0.7188
# Epoch 95: saving model to checkpoints\weights.95.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4351 - accuracy: 0.7679
# Epoch 96/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3382 - accuracy: 0.8438
# Epoch 96: saving model to checkpoints\weights.96.hdf5
# 38/38 [==============================] - 0s 946us/step - loss: 0.4348 - accuracy: 0.7696
# Epoch 97/100
#  1/38 [..............................] - ETA: 0s - loss: 0.5047 - accuracy: 0.7812
# Epoch 97: saving model to checkpoints\weights.97.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4345 - accuracy: 0.7754
# Epoch 98/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3764 - accuracy: 0.8438
# Epoch 98: saving model to checkpoints\weights.98.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4361 - accuracy: 0.7671
# Epoch 99/100
#  1/38 [..............................] - ETA: 0s - loss: 0.4167 - accuracy: 0.7500
# Epoch 99: saving model to checkpoints\weights.99.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.7687
# Epoch 100/100
#  1/38 [..............................] - ETA: 0s - loss: 0.3943 - accuracy: 0.8438
# Epoch 100: saving model to checkpoints\weights.100.hdf5
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.7729

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# when brand 1, all states, accuracy = 36%
# when brand 2, all states, accuracy = 36%
# when brand 3, all states, accuracy = 36%

# B1, CA = 78%
# B2, CA = 80%
# B3, CA = 77%

# B3, PA = 100%
# B3, TX = 76%
# Out:
# 13/13 - 0s - loss: 0.4908 - accuracy: 0.7157 - 108ms/epoch - 8ms/step
# Loss: 0.49083954095840454, Accuracy: 0.7157106995582581

# %% [markdown]
# ### B1 Results

# %%
data_results_b1 = {
        'State': ['CA', 'TX', 'NE', 'AL', 'NJ', 'NC', 'OR', 'LA'],
        'Predictive Accuracy': [.78, .74, .89, .84, .74, .74, .87, .71],
        'Tier': ['T1', 'T1', 'T4', 'T4', 'T3', 'T3', 'T2', 'T2']}
data_results_b1
# Out:
# {'State': ['CA', 'TX', 'NE', 'AL', 'NJ', 'NC', 'OR', 'LA'],
#  'Predictive Accuracy': [0.78, 0.74, 0.89, 0.84, 0.74, 0.74, 0.87, 0.71],
#  'Tier': ['T1', 'T1', 'T4', 'T4', 'T3', 'T3', 'T2', 'T2']}

# %%
# create the new df to display brand, state, and model accuracy 
df_results_b1 = pd.DataFrame(data_results_b1)
df_results_b1
# Out:
#   State  Predictive Accuracy Tier
# 0    CA                 0.78   T1
# 1    TX                 0.74   T1
# 2    NE                 0.89   T4
# 3    AL                 0.84   T4
# 4    NJ                 0.74   T3
# 5    NC                 0.74   T3
# 6    OR                 0.87   T2
# 7    LA                 0.71   T2

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd 

# Import and read the charity_data.csv.
uncleanDf = pd.read_csv("PostPerf.csv")
uncleanDf.head()
# Out:
#               Date                          Post ID   Network Post Type  \
# 0  8/14/2020 10:51  112290707228136_131391708651369  Facebook      Post
# 1  9/21/2020 16:48  112290707228136_147495937040946  Facebook      Post
# 2  9/16/2020 17:06  112290707228136_145518423905364  Facebook      Post
# 3  9/14/2020 16:56  112290707228136_144629800660893  Facebook      Post
# 4  3/31/2022 14:56  112290707228136_646186449954072  Facebook      Post
#
#   Content Type   Profile                                               Link  \
# 0        Video  Lumentum  https://www.facebook.com/112290707228136/posts...
# 1        Photo  Lumentum  https://www.facebook.com/112290707228136/posts...
# 2        Photo  Lumentum  https://www.facebook.com/112290707228136/posts...
# 3        Photo  Lumentum  https://www.facebook.com/112290707228136/posts...
# 4        Video  Lumentum  https://www.facebook.com/440463813859671/posts...
#
#                                                 Post  \
# 0  Meet Chi Tran Thi Phuong, our IT Supply Chain ...
# 1  Meet our team in Thailand! \n\nThailand, home ...
# 2  Meet our team in Slovenia! \n\nLumentum’s Slov...
# 3  In Japan, Lumentum has teams in Sagamihara and...
# 4  Today's the last day of Women's History Month....
#
#                                       Linked Content Impressions  ...  \
# 0  https://www.facebook.com/112290707228136/video...         819  ...
# 1  https://www.facebook.com/112290707228136/photo...         401  ...
# 2  https://www.facebook.com/112290707228136/photo...         281  ...
# 3  https://www.facebook.com/112290707228136/photo...          62  ...
# 4  https://www.facebook.com/440463813859671/video...         243  ...
#
#   Subscribers Lost from Video Video Removed from Playlists  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Annotation Impressions  Annotation Clickable Impressions  \
# 0                     NaN                               NaN
# 1                     NaN                               NaN
# 2                     NaN                               NaN
# 3                     NaN                               NaN
# 4                     NaN                               NaN
#
#    Annotation Closable Impressions  Annotation Closes  Card Impressions  \
# 0                              NaN                NaN               NaN
# 1                              NaN                NaN               NaN
# 2                              NaN                NaN               NaN
# 3                              NaN                NaN               NaN
# 4                              NaN                NaN               NaN
#
#   Card Teaser Impressions Card Teaser Clicks                        Tags
# 0                     NaN                NaN                         NaN
# 1                     NaN                NaN                         NaN
# 2                     NaN                NaN                         NaN
# 3                     NaN                NaN                         NaN
# 4                     NaN                NaN  DIB, Women's History Month
#
# [5 rows x 132 columns]

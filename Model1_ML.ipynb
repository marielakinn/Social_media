# %% [markdown]
# # Neural Network Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the csv.
df = pd.read_csv('model_df1_official.csv', index_col=[0])
df.head()
# Out:
#      spend  Impressions  leads  State Tiers  Agency Tiers
# 770   7.28          427    0.0            4             4
# 771  13.32         1042    1.0            4             4
# 772  10.11          337    0.0            4             4
# 773   0.00            0    1.0            4             4
# 774   7.35          379    1.0            4             4

# %%
df['leads'].value_counts()
# Out:
# 1.0    87830
# 0.0    69842
# Name: leads, dtype: int64

# %%
df2 = df.drop(columns=['State Tiers', 'Agency Tiers'])
df2
# Out:
#         spend  Impressions  leads
# 770      7.28          427    0.0
# 771     13.32         1042    1.0
# 772     10.11          337    0.0
# 773      0.00            0    1.0
# 774      7.35          379    1.0
# ...       ...          ...    ...
# 160480   2.01           43    0.0
# 160481   1.38           31    0.0
# 160482  11.27          673    0.0
# 160483  11.34          800    0.0
# 160484   9.27          465    0.0
#
# [157672 rows x 3 columns]

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = df2['leads'].values
X = df2.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have X amount of columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 300
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 150
# layer 3 = hidden layer
layer3= 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="relu")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="relu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='relu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 300)               900
#
#  dense_1 (Dense)             (None, 150)               45150
#
#  dense_2 (Dense)             (None, 20)                3020
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 49,091
# Trainable params: 49,091
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 3690/3696 [============================>.] - ETA: 0s - loss: 0.6870 - accuracy: 0.5568
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6870 - accuracy: 0.5568
# Epoch 2/100
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6867 - accuracy: 0.5569
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6867 - accuracy: 0.5570
# Epoch 3/100
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6866 - accuracy: 0.5570
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6866 - accuracy: 0.5570
# Epoch 4/100
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6867 - accuracy: 0.5570
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6867 - accuracy: 0.5570
# Epoch 5/100
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6865 - accuracy: 0.5570
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6865 - accuracy: 0.5569
# Epoch 6/100
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5570
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6865 - accuracy: 0.5570
# Epoch 7/100
# 3694/3696 [============================>.] - ETA: 0s - loss: 0.6865 - accuracy: 0.5569
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6865 - accuracy: 0.5569
# Epoch 8/100
# 3658/3696 [============================>.] - ETA: 0s - loss: 0.6865 - accuracy: 0.5570
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6865 - accuracy: 0.5570
# Epoch 9/100
# 3685/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5570
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6864 - accuracy: 0.5570
# Epoch 10/100
# 3670/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5570
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6864 - accuracy: 0.5569
# Epoch 11/100
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5569
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6864 - accuracy: 0.5569
# Epoch 12/100
# 3668/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5571
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6864 - accuracy: 0.5569
# Epoch 13/100
# 3661/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5568
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6864 - accuracy: 0.5569
# Epoch 14/100
# 3691/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5569
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6864 - accuracy: 0.5569
# Epoch 15/100
# 3669/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5570
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 16/100
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5569
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6864 - accuracy: 0.5569
# Epoch 17/100
# 3666/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5568
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 18/100
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5570
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6864 - accuracy: 0.5570
# Epoch 19/100
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6863 - accuracy: 0.5570
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5570
# Epoch 20/100
# 3684/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5569
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5570
# Epoch 21/100
# 3680/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5570
# Epoch 22/100
# 3678/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5570
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 23/100
# 3663/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 24/100
# 3655/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5572
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5570
# Epoch 25/100
# 3680/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5570
# Epoch 26/100
# 3660/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5568
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 27/100
# 3661/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5571
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5570
# Epoch 28/100
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5571
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5570
# Epoch 29/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5571
# Epoch 30/100
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5571
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 31/100
# 3669/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5572
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5570
# Epoch 32/100
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5571
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5571
# Epoch 33/100
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5570
# Epoch 34/100
# 3666/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5568
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 35/100
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5571
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5570
# Epoch 36/100
# 3691/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5571
# Epoch 37/100
# 3690/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5569
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 38/100
# 3683/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5570
# Epoch 39/100
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6862 - accuracy: 0.5570
# Epoch 40/100
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5571
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5570
# Epoch 41/100
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5569
# Epoch 41: saving model to checkpoints\weights.41.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5570
# Epoch 42/100
# 3689/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570
# Epoch 42: saving model to checkpoints\weights.42.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 43/100
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570
# Epoch 43: saving model to checkpoints\weights.43.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5570
# Epoch 44/100
# 3689/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5569
# Epoch 44: saving model to checkpoints\weights.44.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 45/100
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5571
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5570
# Epoch 46/100
# 3680/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5571
# Epoch 46: saving model to checkpoints\weights.46.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5570
# Epoch 47/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5571
# Epoch 47: saving model to checkpoints\weights.47.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5571
# Epoch 48/100
# 3680/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5571
# Epoch 48: saving model to checkpoints\weights.48.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5571
# Epoch 49/100
# 3671/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5571
# Epoch 49: saving model to checkpoints\weights.49.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5570
# Epoch 50/100
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5572
# Epoch 50: saving model to checkpoints\weights.50.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5570
# Epoch 51/100
# 3680/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5565
# Epoch 51: saving model to checkpoints\weights.51.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5566
# Epoch 52/100
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6860 - accuracy: 0.5569
# Epoch 52: saving model to checkpoints\weights.52.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5569
# Epoch 53/100
# 3669/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5568
# Epoch 53: saving model to checkpoints\weights.53.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5567
# Epoch 54/100
# 3657/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5568
# Epoch 54: saving model to checkpoints\weights.54.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5568
# Epoch 55/100
# 3663/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5573
# Epoch 55: saving model to checkpoints\weights.55.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5572
# Epoch 56/100
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5568
# Epoch 56: saving model to checkpoints\weights.56.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5569
# Epoch 57/100
# 3678/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5567
# Epoch 57: saving model to checkpoints\weights.57.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5570
# Epoch 58/100
# 3695/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5569
# Epoch 58: saving model to checkpoints\weights.58.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5569
# Epoch 59/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5568
# Epoch 59: saving model to checkpoints\weights.59.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5568
# Epoch 60/100
# 3660/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5570
# Epoch 60: saving model to checkpoints\weights.60.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5570
# Epoch 61/100
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5573
# Epoch 61: saving model to checkpoints\weights.61.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5572
# Epoch 62/100
# 3675/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5569
# Epoch 62: saving model to checkpoints\weights.62.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5569
# Epoch 63/100
# 3665/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5572
# Epoch 63: saving model to checkpoints\weights.63.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5569
# Epoch 64/100
# 3684/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5570
# Epoch 64: saving model to checkpoints\weights.64.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5569
# Epoch 65/100
# 3689/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5568
# Epoch 65: saving model to checkpoints\weights.65.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5568
# Epoch 66/100
# 3685/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5570
# Epoch 66: saving model to checkpoints\weights.66.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5569
# Epoch 67/100
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5568
# Epoch 67: saving model to checkpoints\weights.67.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5568
# Epoch 68/100
# 3675/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5568
# Epoch 68: saving model to checkpoints\weights.68.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5570
# Epoch 69/100
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5568
# Epoch 69: saving model to checkpoints\weights.69.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5570
# Epoch 70/100
# 3683/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5569
# Epoch 70: saving model to checkpoints\weights.70.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5568
# Epoch 71/100
# 3667/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5570
# Epoch 71: saving model to checkpoints\weights.71.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5569
# Epoch 72/100
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6859 - accuracy: 0.5569
# Epoch 72: saving model to checkpoints\weights.72.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5569
# Epoch 73/100
# 3663/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5572
# Epoch 73: saving model to checkpoints\weights.73.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5570
# Epoch 74/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5572
# Epoch 74: saving model to checkpoints\weights.74.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5572
# Epoch 75/100
# 3667/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5571
# Epoch 75: saving model to checkpoints\weights.75.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5569
# Epoch 76/100
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5569
# Epoch 76: saving model to checkpoints\weights.76.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5570
# Epoch 77/100
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5568
# Epoch 77: saving model to checkpoints\weights.77.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5569
# Epoch 78/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5571
# Epoch 78: saving model to checkpoints\weights.78.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5572
# Epoch 79/100
# 3666/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5570
# Epoch 79: saving model to checkpoints\weights.79.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5570
# Epoch 80/100
# 3670/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5571
# Epoch 80: saving model to checkpoints\weights.80.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5570
# Epoch 81/100
# 3670/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5566
# Epoch 81: saving model to checkpoints\weights.81.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5568
# Epoch 82/100
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5573
# Epoch 82: saving model to checkpoints\weights.82.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5571
# Epoch 83/100
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5569
# Epoch 83: saving model to checkpoints\weights.83.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5571
# Epoch 84/100
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.5570
# Epoch 84: saving model to checkpoints\weights.84.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6860 - accuracy: 0.5570
# Epoch 85/100
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5570
# Epoch 85: saving model to checkpoints\weights.85.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5569
# Epoch 86/100
# 3685/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5570
# Epoch 86: saving model to checkpoints\weights.86.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5570
# Epoch 87/100
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5571
# Epoch 87: saving model to checkpoints\weights.87.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5572
# Epoch 88/100
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5571
# Epoch 88: saving model to checkpoints\weights.88.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5571
# Epoch 89/100
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5569
# Epoch 89: saving model to checkpoints\weights.89.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5571
# Epoch 90/100
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5571
# Epoch 90: saving model to checkpoints\weights.90.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6861 - accuracy: 0.5570
# Epoch 91/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.5572
# Epoch 91: saving model to checkpoints\weights.91.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6859 - accuracy: 0.5572
# Epoch 92/100
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6857 - accuracy: 0.5570
# Epoch 92: saving model to checkpoints\weights.92.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6857 - accuracy: 0.5571
# Epoch 93/100
# 3694/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5571
# Epoch 93: saving model to checkpoints\weights.93.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5571
# Epoch 94/100
# 3666/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5568
# Epoch 94: saving model to checkpoints\weights.94.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5569
# Epoch 95/100
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6857 - accuracy: 0.5571
# Epoch 95: saving model to checkpoints\weights.95.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6857 - accuracy: 0.5571
# Epoch 96/100
# 3678/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5571
# Epoch 96: saving model to checkpoints\weights.96.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5570
# Epoch 97/100
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6857 - accuracy: 0.5575
# Epoch 97: saving model to checkpoints\weights.97.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5574
# Epoch 98/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5572
# Epoch 98: saving model to checkpoints\weights.98.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5571
# Epoch 99/100
# 3668/3696 [============================>.] - ETA: 0s - loss: 0.6857 - accuracy: 0.5574
# Epoch 99: saving model to checkpoints\weights.99.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6857 - accuracy: 0.5573
# Epoch 100/100
# 3695/3696 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5572
# Epoch 100: saving model to checkpoints\weights.100.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6858 - accuracy: 0.5572

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1232/1232 - 1s - loss: 0.6864 - accuracy: 0.5574 - 1s/epoch - 981us/step
# Loss: 0.6864300966262817, Accuracy: 0.5573595762252808

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")

# %% [markdown]
# # Neural Network Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the csv.
df = pd.read_csv('model_df1_official.csv', index_col=[0])
df.head()
# Out:
#      spend  Impressions  leads  State Tiers  Agency Tiers
# 770   7.28          427    0.0            4             4
# 771  13.32         1042    1.0            4             4
# 772  10.11          337    0.0            4             4
# 773   0.00            0    1.0            4             4
# 774   7.35          379    1.0            4             4

# %%
df['leads'].value_counts()
# Out:
# 1.0    87830
# 0.0    69842
# Name: leads, dtype: int64

# %%
df2 = df.drop(columns=['State Tiers', 'Agency Tiers'])
df2
# Out:
#         spend  Impressions  leads
# 770      7.28          427    0.0
# 771     13.32         1042    1.0
# 772     10.11          337    0.0
# 773      0.00            0    1.0
# 774      7.35          379    1.0
# ...       ...          ...    ...
# 160480   2.01           43    0.0
# 160481   1.38           31    0.0
# 160482  11.27          673    0.0
# 160483  11.34          800    0.0
# 160484   9.27          465    0.0
#
# [157672 rows x 3 columns]

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = df2['leads'].values
X = df2.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have X amount of columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 300
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 150
# layer 3 = hidden layer
layer3= 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="relu")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="relu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='relu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                150
#
#  dense_1 (Dense)             (None, 25)                1275
#
#  dense_2 (Dense)             (None, 5)                 130
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1,561
# Trainable params: 1,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/200
# 3650/3696 [============================>.] - ETA: 0s - loss: 0.6869 - accuracy: 0.5568
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 3696/3696 [==============================] - 4s 964us/step - loss: 0.6870 - accuracy: 0.5566
# Epoch 2/200
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6866 - accuracy: 0.5569
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 3696/3696 [==============================] - 4s 973us/step - loss: 0.6866 - accuracy: 0.5569
# Epoch 3/200
# 3663/3696 [============================>.] - ETA: 0s - loss: 0.6865 - accuracy: 0.5570
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 3696/3696 [==============================] - 4s 990us/step - loss: 0.6865 - accuracy: 0.5569
# Epoch 4/200
# 3652/3696 [============================>.] - ETA: 0s - loss: 0.6865 - accuracy: 0.5570
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 3696/3696 [==============================] - 4s 981us/step - loss: 0.6865 - accuracy: 0.5569
# Epoch 5/200
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5570
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 3696/3696 [==============================] - 4s 987us/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 6/200
# 3687/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5569
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 3696/3696 [==============================] - 4s 997us/step - loss: 0.6864 - accuracy: 0.5569
# Epoch 7/200
# 3675/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5571
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 3696/3696 [==============================] - 4s 1ms/step - loss: 0.6864 - accuracy: 0.5569
# Epoch 8/200
# 3663/3696 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5569
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 3696/3696 [==============================] - 4s 990us/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 9/200
# 3646/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5571
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 3696/3696 [==============================] - 4s 953us/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 10/200
# 3669/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5569
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 3696/3696 [==============================] - 4s 987us/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 11/200
# 3682/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5570
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 3696/3696 [==============================] - 4s 1ms/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 12/200
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5570
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 3696/3696 [==============================] - 4s 955us/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 13/200
# 3654/3696 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.5569
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 3696/3696 [==============================] - 4s 949us/step - loss: 0.6863 - accuracy: 0.5569
# Epoch 14/200
# 3684/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 3696/3696 [==============================] - 4s 955us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 15/200
# 3669/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5571
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 3696/3696 [==============================] - 4s 947us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 16/200
# 3695/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 3696/3696 [==============================] - 3s 939us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 17/200
# 3667/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5571
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 3696/3696 [==============================] - 4s 976us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 18/200
# 3645/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 3696/3696 [==============================] - 4s 966us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 19/200
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 3696/3696 [==============================] - 4s 962us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 20/200
# 3661/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 3696/3696 [==============================] - 4s 948us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 21/200
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5571
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 3696/3696 [==============================] - 4s 950us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 22/200
# 3670/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 3696/3696 [==============================] - 3s 947us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 23/200
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 3696/3696 [==============================] - 4s 948us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 24/200
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 3696/3696 [==============================] - 4s 948us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 25/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 3696/3696 [==============================] - 3s 938us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 26/200
# 3656/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5572
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 3696/3696 [==============================] - 3s 922us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 27/200
# 3666/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5568
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 3696/3696 [==============================] - 3s 905us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 28/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 3696/3696 [==============================] - 4s 952us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 29/200
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5571
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 3696/3696 [==============================] - 3s 932us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 30/200
# 3651/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5571
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 3696/3696 [==============================] - 3s 908us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 31/200
# 3680/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5568
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 3696/3696 [==============================] - 3s 929us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 32/200
# 3657/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5570
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 3696/3696 [==============================] - 3s 920us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 33/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 3696/3696 [==============================] - 3s 925us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 34/200
# 3687/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5569
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 3696/3696 [==============================] - 3s 941us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 35/200
# 3681/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 3696/3696 [==============================] - 3s 929us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 36/200
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 3696/3696 [==============================] - 3s 926us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 37/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 3696/3696 [==============================] - 4s 952us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 38/200
# 3691/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 3696/3696 [==============================] - 3s 926us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 39/200
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 3696/3696 [==============================] - 3s 944us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 40/200
# 3663/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 3696/3696 [==============================] - 3s 946us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 41/200
# 3651/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5569
# Epoch 41: saving model to checkpoints\weights.41.hdf5
# 3696/3696 [==============================] - 4s 951us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 42/200
# 3667/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5569
# Epoch 42: saving model to checkpoints\weights.42.hdf5
# 3696/3696 [==============================] - 4s 974us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 43/200
# 3655/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5567
# Epoch 43: saving model to checkpoints\weights.43.hdf5
# 3696/3696 [==============================] - 4s 977us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 44/200
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5569
# Epoch 44: saving model to checkpoints\weights.44.hdf5
# 3696/3696 [==============================] - 4s 957us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 45/200
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 3696/3696 [==============================] - 4s 966us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 46/200
# 3649/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5572
# Epoch 46: saving model to checkpoints\weights.46.hdf5
# 3696/3696 [==============================] - 4s 979us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 47/200
# 3683/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5569
# Epoch 47: saving model to checkpoints\weights.47.hdf5
# 3696/3696 [==============================] - 3s 943us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 48/200
# 3657/3696 [============================>.] - ETA: 0s - loss: 0.6862 - accuracy: 0.5569
# Epoch 48: saving model to checkpoints\weights.48.hdf5
# 3696/3696 [==============================] - 4s 964us/step - loss: 0.6862 - accuracy: 0.5569
# Epoch 49/200
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570
# Epoch 49: saving model to checkpoints\weights.49.hdf5
# 3696/3696 [==============================] - 3s 944us/step - loss: 0.6861 - accuracy: 0.5569
# Epoch 50/200
# 3224/3696 [=========================>....] - ETA: 0s - loss: 0.6861 - accuracy: 0.5570

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")

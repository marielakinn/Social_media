# %% [markdown]
# # Neural Network Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the charity_data.csv.
df = pd.read_csv('model_df1_official.csv')
df.head()
# Out:
#    Unnamed: 0  spend  Impressions  leads  State Tiers  Agency Tiers
# 0         770   7.28          427    0.0            4             4
# 1         771  13.32         1042    1.0            4             4
# 2         772  10.11          337    0.0            4             4
# 3         773   0.00            0    1.0            4             4
# 4         774   7.35          379    1.0            4             4

# %%
df['leads'].value_counts()
# Out:
# 1.0    87830
# 0.0    69842
# Name: leads, dtype: int64

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = df['leads'].values
X = df.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have X amount of columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 20
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 10
# layer 3 = hidden layer
layer3= 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="relu")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="relu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='relu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                120
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 391
# Trainable params: 391
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=200,callbacks=[cp_callback])
# Out:
# Epoch 1/200
# 3646/3696 [============================>.] - ETA: 0s - loss: 0.6824 - accuracy: 0.5608
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 3696/3696 [==============================] - 3s 840us/step - loss: 0.6824 - accuracy: 0.5609
# Epoch 2/200
# 3660/3696 [============================>.] - ETA: 0s - loss: 0.6796 - accuracy: 0.5656
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 3696/3696 [==============================] - 3s 851us/step - loss: 0.6796 - accuracy: 0.5656
# Epoch 3/200
# 3657/3696 [============================>.] - ETA: 0s - loss: 0.6786 - accuracy: 0.5695
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 3696/3696 [==============================] - 3s 865us/step - loss: 0.6786 - accuracy: 0.5696
# Epoch 4/200
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6777 - accuracy: 0.5703
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 3696/3696 [==============================] - 3s 831us/step - loss: 0.6777 - accuracy: 0.5703
# Epoch 5/200
# 3668/3696 [============================>.] - ETA: 0s - loss: 0.6773 - accuracy: 0.5708
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 3696/3696 [==============================] - 3s 836us/step - loss: 0.6773 - accuracy: 0.5706
# Epoch 6/200
# 3650/3696 [============================>.] - ETA: 0s - loss: 0.6769 - accuracy: 0.5706
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 3696/3696 [==============================] - 3s 811us/step - loss: 0.6769 - accuracy: 0.5706
# Epoch 7/200
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6767 - accuracy: 0.5704
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 3696/3696 [==============================] - 3s 808us/step - loss: 0.6768 - accuracy: 0.5702
# Epoch 8/200
# 3640/3696 [============================>.] - ETA: 0s - loss: 0.6768 - accuracy: 0.5715
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 3696/3696 [==============================] - 3s 813us/step - loss: 0.6767 - accuracy: 0.5716
# Epoch 9/200
# 3661/3696 [============================>.] - ETA: 0s - loss: 0.6766 - accuracy: 0.5707
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 3696/3696 [==============================] - 3s 852us/step - loss: 0.6766 - accuracy: 0.5707
# Epoch 10/200
# 3655/3696 [============================>.] - ETA: 0s - loss: 0.6763 - accuracy: 0.5710
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 3696/3696 [==============================] - 3s 937us/step - loss: 0.6764 - accuracy: 0.5707
# Epoch 11/200
# 3685/3696 [============================>.] - ETA: 0s - loss: 0.6763 - accuracy: 0.5714
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 3696/3696 [==============================] - 3s 831us/step - loss: 0.6764 - accuracy: 0.5713
# Epoch 12/200
# 3690/3696 [============================>.] - ETA: 0s - loss: 0.6762 - accuracy: 0.5712
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 3696/3696 [==============================] - 3s 914us/step - loss: 0.6762 - accuracy: 0.5712
# Epoch 13/200
# 3658/3696 [============================>.] - ETA: 0s - loss: 0.6758 - accuracy: 0.5713
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 3696/3696 [==============================] - 4s 963us/step - loss: 0.6759 - accuracy: 0.5710
# Epoch 14/200
# 3694/3696 [============================>.] - ETA: 0s - loss: 0.6757 - accuracy: 0.5724
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 3696/3696 [==============================] - 3s 898us/step - loss: 0.6757 - accuracy: 0.5724
# Epoch 15/200
# 3684/3696 [============================>.] - ETA: 0s - loss: 0.6755 - accuracy: 0.5725
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 3696/3696 [==============================] - 3s 928us/step - loss: 0.6755 - accuracy: 0.5726
# Epoch 16/200
# 3661/3696 [============================>.] - ETA: 0s - loss: 0.6752 - accuracy: 0.5723
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 3696/3696 [==============================] - 3s 935us/step - loss: 0.6753 - accuracy: 0.5720
# Epoch 17/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6752 - accuracy: 0.5734
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 3696/3696 [==============================] - 3s 912us/step - loss: 0.6752 - accuracy: 0.5734
# Epoch 18/200
# 3645/3696 [============================>.] - ETA: 0s - loss: 0.6751 - accuracy: 0.5737
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 3696/3696 [==============================] - 3s 924us/step - loss: 0.6751 - accuracy: 0.5737
# Epoch 19/200
# 3666/3696 [============================>.] - ETA: 0s - loss: 0.6748 - accuracy: 0.5743
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 3696/3696 [==============================] - 3s 918us/step - loss: 0.6749 - accuracy: 0.5742
# Epoch 20/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6749 - accuracy: 0.5745
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 3696/3696 [==============================] - 3s 897us/step - loss: 0.6749 - accuracy: 0.5745
# Epoch 21/200
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6745 - accuracy: 0.5756
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 3696/3696 [==============================] - 3s 901us/step - loss: 0.6746 - accuracy: 0.5755
# Epoch 22/200
# 3681/3696 [============================>.] - ETA: 0s - loss: 0.6750 - accuracy: 0.5747
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 3696/3696 [==============================] - 3s 874us/step - loss: 0.6750 - accuracy: 0.5747
# Epoch 23/200
# 3657/3696 [============================>.] - ETA: 0s - loss: 0.6748 - accuracy: 0.5761
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6748 - accuracy: 0.5759
# Epoch 24/200
# 3680/3696 [============================>.] - ETA: 0s - loss: 0.6746 - accuracy: 0.5745
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 3696/3696 [==============================] - 3s 873us/step - loss: 0.6746 - accuracy: 0.5745
# Epoch 25/200
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6744 - accuracy: 0.5754
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 3696/3696 [==============================] - 3s 876us/step - loss: 0.6744 - accuracy: 0.5754
# Epoch 26/200
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6747 - accuracy: 0.5769
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 3696/3696 [==============================] - 3s 887us/step - loss: 0.6747 - accuracy: 0.5769
# Epoch 27/200
# 3687/3696 [============================>.] - ETA: 0s - loss: 0.6744 - accuracy: 0.5757
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 3696/3696 [==============================] - 3s 887us/step - loss: 0.6744 - accuracy: 0.5757
# Epoch 28/200
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6743 - accuracy: 0.5755
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 3696/3696 [==============================] - 3s 878us/step - loss: 0.6743 - accuracy: 0.5755
# Epoch 29/200
# 3656/3696 [============================>.] - ETA: 0s - loss: 0.6742 - accuracy: 0.5767
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6742 - accuracy: 0.5767
# Epoch 30/200
# 3660/3696 [============================>.] - ETA: 0s - loss: 0.6740 - accuracy: 0.5776
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 3696/3696 [==============================] - 3s 864us/step - loss: 0.6741 - accuracy: 0.5774
# Epoch 31/200
# 3665/3696 [============================>.] - ETA: 0s - loss: 0.6742 - accuracy: 0.5778
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 3696/3696 [==============================] - 3s 892us/step - loss: 0.6741 - accuracy: 0.5779
# Epoch 32/200
# 3650/3696 [============================>.] - ETA: 0s - loss: 0.6740 - accuracy: 0.5759
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 3696/3696 [==============================] - 3s 895us/step - loss: 0.6739 - accuracy: 0.5761
# Epoch 33/200
# 3678/3696 [============================>.] - ETA: 0s - loss: 0.6738 - accuracy: 0.5767
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 3696/3696 [==============================] - 3s 929us/step - loss: 0.6737 - accuracy: 0.5768
# Epoch 34/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6739 - accuracy: 0.5775
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 3696/3696 [==============================] - 3s 898us/step - loss: 0.6739 - accuracy: 0.5775
# Epoch 35/200
# 3671/3696 [============================>.] - ETA: 0s - loss: 0.6735 - accuracy: 0.5776
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 3696/3696 [==============================] - 3s 917us/step - loss: 0.6736 - accuracy: 0.5774
# Epoch 36/200
# 3651/3696 [============================>.] - ETA: 0s - loss: 0.6735 - accuracy: 0.5784
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 3696/3696 [==============================] - 3s 882us/step - loss: 0.6736 - accuracy: 0.5780
# Epoch 37/200
# 3687/3696 [============================>.] - ETA: 0s - loss: 0.6736 - accuracy: 0.5780
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 3696/3696 [==============================] - 3s 873us/step - loss: 0.6736 - accuracy: 0.5780
# Epoch 38/200
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6740 - accuracy: 0.5772
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 3696/3696 [==============================] - 3s 930us/step - loss: 0.6739 - accuracy: 0.5773
# Epoch 39/200
# 3687/3696 [============================>.] - ETA: 0s - loss: 0.6733 - accuracy: 0.5778
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 3696/3696 [==============================] - 3s 872us/step - loss: 0.6733 - accuracy: 0.5778
# Epoch 40/200
# 3657/3696 [============================>.] - ETA: 0s - loss: 0.6735 - accuracy: 0.5780
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 3696/3696 [==============================] - 3s 880us/step - loss: 0.6735 - accuracy: 0.5780
# Epoch 41/200
# 3675/3696 [============================>.] - ETA: 0s - loss: 0.6734 - accuracy: 0.5786
# Epoch 41: saving model to checkpoints\weights.41.hdf5
# 3696/3696 [==============================] - 3s 861us/step - loss: 0.6734 - accuracy: 0.5787
# Epoch 42/200
# 3665/3696 [============================>.] - ETA: 0s - loss: 0.6734 - accuracy: 0.5778
# Epoch 42: saving model to checkpoints\weights.42.hdf5
# 3696/3696 [==============================] - 3s 864us/step - loss: 0.6733 - accuracy: 0.5780
# Epoch 43/200
# 3642/3696 [============================>.] - ETA: 0s - loss: 0.6732 - accuracy: 0.5790
# Epoch 43: saving model to checkpoints\weights.43.hdf5
# 3696/3696 [==============================] - 3s 870us/step - loss: 0.6732 - accuracy: 0.5790
# Epoch 44/200
# 3685/3696 [============================>.] - ETA: 0s - loss: 0.6733 - accuracy: 0.5792
# Epoch 44: saving model to checkpoints\weights.44.hdf5
# 3696/3696 [==============================] - 3s 886us/step - loss: 0.6733 - accuracy: 0.5793
# Epoch 45/200
# 3653/3696 [============================>.] - ETA: 0s - loss: 0.6733 - accuracy: 0.5784
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6733 - accuracy: 0.5785
# Epoch 46/200
# 3687/3696 [============================>.] - ETA: 0s - loss: 0.6734 - accuracy: 0.5780
# Epoch 46: saving model to checkpoints\weights.46.hdf5
# 3696/3696 [==============================] - 3s 886us/step - loss: 0.6733 - accuracy: 0.5781
# Epoch 47/200
# 3678/3696 [============================>.] - ETA: 0s - loss: 0.6730 - accuracy: 0.5783
# Epoch 47: saving model to checkpoints\weights.47.hdf5
# 3696/3696 [==============================] - 3s 888us/step - loss: 0.6729 - accuracy: 0.5785
# Epoch 48/200
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6731 - accuracy: 0.5782
# Epoch 48: saving model to checkpoints\weights.48.hdf5
# 3696/3696 [==============================] - 3s 888us/step - loss: 0.6731 - accuracy: 0.5782
# Epoch 49/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6730 - accuracy: 0.5793
# Epoch 49: saving model to checkpoints\weights.49.hdf5
# 3696/3696 [==============================] - 3s 869us/step - loss: 0.6731 - accuracy: 0.5791
# Epoch 50/200
# 3680/3696 [============================>.] - ETA: 0s - loss: 0.6728 - accuracy: 0.5795
# Epoch 50: saving model to checkpoints\weights.50.hdf5
# 3696/3696 [==============================] - 3s 888us/step - loss: 0.6729 - accuracy: 0.5794
# Epoch 51/200
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6729 - accuracy: 0.5779
# Epoch 51: saving model to checkpoints\weights.51.hdf5
# 3696/3696 [==============================] - 3s 934us/step - loss: 0.6730 - accuracy: 0.5780
# Epoch 52/200
# 3668/3696 [============================>.] - ETA: 0s - loss: 0.6729 - accuracy: 0.5791
# Epoch 52: saving model to checkpoints\weights.52.hdf5
# 3696/3696 [==============================] - 3s 891us/step - loss: 0.6728 - accuracy: 0.5792
# Epoch 53/200
# 3685/3696 [============================>.] - ETA: 0s - loss: 0.6729 - accuracy: 0.5791
# Epoch 53: saving model to checkpoints\weights.53.hdf5
# 3696/3696 [==============================] - 3s 873us/step - loss: 0.6729 - accuracy: 0.5790
# Epoch 54/200
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.5791
# Epoch 54: saving model to checkpoints\weights.54.hdf5
# 3696/3696 [==============================] - 3s 942us/step - loss: 0.6726 - accuracy: 0.5790
# Epoch 55/200
# 3649/3696 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.5791
# Epoch 55: saving model to checkpoints\weights.55.hdf5
# 3696/3696 [==============================] - 3s 906us/step - loss: 0.6726 - accuracy: 0.5793
# Epoch 56/200
# 3655/3696 [============================>.] - ETA: 0s - loss: 0.6727 - accuracy: 0.5784
# Epoch 56: saving model to checkpoints\weights.56.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6726 - accuracy: 0.5784
# Epoch 57/200
# 3668/3696 [============================>.] - ETA: 0s - loss: 0.6727 - accuracy: 0.5787
# Epoch 57: saving model to checkpoints\weights.57.hdf5
# 3696/3696 [==============================] - 3s 891us/step - loss: 0.6727 - accuracy: 0.5787
# Epoch 58/200
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6725 - accuracy: 0.5803
# Epoch 58: saving model to checkpoints\weights.58.hdf5
# 3696/3696 [==============================] - 3s 877us/step - loss: 0.6725 - accuracy: 0.5802
# Epoch 59/200
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.5789
# Epoch 59: saving model to checkpoints\weights.59.hdf5
# 3696/3696 [==============================] - 3s 940us/step - loss: 0.6726 - accuracy: 0.5789
# Epoch 60/200
# 3682/3696 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.5790
# Epoch 60: saving model to checkpoints\weights.60.hdf5
# 3696/3696 [==============================] - 3s 900us/step - loss: 0.6725 - accuracy: 0.5791
# Epoch 61/200
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6725 - accuracy: 0.5787
# Epoch 61: saving model to checkpoints\weights.61.hdf5
# 3696/3696 [==============================] - 3s 870us/step - loss: 0.6725 - accuracy: 0.5787
# Epoch 62/200
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6725 - accuracy: 0.5796
# Epoch 62: saving model to checkpoints\weights.62.hdf5
# 3696/3696 [==============================] - 3s 851us/step - loss: 0.6725 - accuracy: 0.5796
# Epoch 63/200
# 3684/3696 [============================>.] - ETA: 0s - loss: 0.6724 - accuracy: 0.5790
# Epoch 63: saving model to checkpoints\weights.63.hdf5
# 3696/3696 [==============================] - 3s 859us/step - loss: 0.6724 - accuracy: 0.5791
# Epoch 64/200
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6723 - accuracy: 0.5802
# Epoch 64: saving model to checkpoints\weights.64.hdf5
# 3696/3696 [==============================] - 3s 863us/step - loss: 0.6724 - accuracy: 0.5802
# Epoch 65/200
# 3647/3696 [============================>.] - ETA: 0s - loss: 0.6723 - accuracy: 0.5792
# Epoch 65: saving model to checkpoints\weights.65.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6722 - accuracy: 0.5795
# Epoch 66/200
# 3690/3696 [============================>.] - ETA: 0s - loss: 0.6724 - accuracy: 0.5794
# Epoch 66: saving model to checkpoints\weights.66.hdf5
# 3696/3696 [==============================] - 3s 843us/step - loss: 0.6724 - accuracy: 0.5794
# Epoch 67/200
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6724 - accuracy: 0.5799
# Epoch 67: saving model to checkpoints\weights.67.hdf5
# 3696/3696 [==============================] - 3s 917us/step - loss: 0.6724 - accuracy: 0.5799
# Epoch 68/200
# 3666/3696 [============================>.] - ETA: 0s - loss: 0.6722 - accuracy: 0.5792
# Epoch 68: saving model to checkpoints\weights.68.hdf5
# 3696/3696 [==============================] - 3s 918us/step - loss: 0.6722 - accuracy: 0.5794
# Epoch 69/200
# 3684/3696 [============================>.] - ETA: 0s - loss: 0.6723 - accuracy: 0.5796
# Epoch 69: saving model to checkpoints\weights.69.hdf5
# 3696/3696 [==============================] - 3s 886us/step - loss: 0.6723 - accuracy: 0.5797
# Epoch 70/200
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6721 - accuracy: 0.5802
# Epoch 70: saving model to checkpoints\weights.70.hdf5
# 3696/3696 [==============================] - 3s 900us/step - loss: 0.6721 - accuracy: 0.5802
# Epoch 71/200
# 3656/3696 [============================>.] - ETA: 0s - loss: 0.6722 - accuracy: 0.5800
# Epoch 71: saving model to checkpoints\weights.71.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6721 - accuracy: 0.5801
# Epoch 72/200
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6721 - accuracy: 0.5798
# Epoch 72: saving model to checkpoints\weights.72.hdf5
# 3696/3696 [==============================] - 3s 889us/step - loss: 0.6720 - accuracy: 0.5799
# Epoch 73/200
# 3649/3696 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.5806
# Epoch 73: saving model to checkpoints\weights.73.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6719 - accuracy: 0.5806
# Epoch 74/200
# 3685/3696 [============================>.] - ETA: 0s - loss: 0.6720 - accuracy: 0.5816
# Epoch 74: saving model to checkpoints\weights.74.hdf5
# 3696/3696 [==============================] - 3s 872us/step - loss: 0.6720 - accuracy: 0.5816
# Epoch 75/200
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.5811
# Epoch 75: saving model to checkpoints\weights.75.hdf5
# 3696/3696 [==============================] - 3s 861us/step - loss: 0.6720 - accuracy: 0.5810
# Epoch 76/200
# 3654/3696 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.5804
# Epoch 76: saving model to checkpoints\weights.76.hdf5
# 3696/3696 [==============================] - 3s 865us/step - loss: 0.6719 - accuracy: 0.5805
# Epoch 77/200
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6720 - accuracy: 0.5808
# Epoch 77: saving model to checkpoints\weights.77.hdf5
# 3696/3696 [==============================] - 3s 892us/step - loss: 0.6720 - accuracy: 0.5808
# Epoch 78/200
# 3670/3696 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.5807
# Epoch 78: saving model to checkpoints\weights.78.hdf5
# 3696/3696 [==============================] - 3s 903us/step - loss: 0.6718 - accuracy: 0.5808
# Epoch 79/200
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6720 - accuracy: 0.5802
# Epoch 79: saving model to checkpoints\weights.79.hdf5
# 3696/3696 [==============================] - 3s 878us/step - loss: 0.6719 - accuracy: 0.5803
# Epoch 80/200
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6718 - accuracy: 0.5806
# Epoch 80: saving model to checkpoints\weights.80.hdf5
# 3696/3696 [==============================] - 3s 912us/step - loss: 0.6718 - accuracy: 0.5806
# Epoch 81/200
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6718 - accuracy: 0.5811
# Epoch 81: saving model to checkpoints\weights.81.hdf5
# 3696/3696 [==============================] - 3s 887us/step - loss: 0.6718 - accuracy: 0.5811
# Epoch 82/200
# 3641/3696 [============================>.] - ETA: 0s - loss: 0.6718 - accuracy: 0.5815
# Epoch 82: saving model to checkpoints\weights.82.hdf5
# 3696/3696 [==============================] - 3s 896us/step - loss: 0.6718 - accuracy: 0.5814
# Epoch 83/200
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.5806
# Epoch 83: saving model to checkpoints\weights.83.hdf5
# 3696/3696 [==============================] - 3s 884us/step - loss: 0.6719 - accuracy: 0.5806
# Epoch 84/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6718 - accuracy: 0.5799
# Epoch 84: saving model to checkpoints\weights.84.hdf5
# 3696/3696 [==============================] - 3s 925us/step - loss: 0.6718 - accuracy: 0.5799
# Epoch 85/200
# 3653/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5808
# Epoch 85: saving model to checkpoints\weights.85.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6717 - accuracy: 0.5807
# Epoch 86/200
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6718 - accuracy: 0.5805
# Epoch 86: saving model to checkpoints\weights.86.hdf5
# 3696/3696 [==============================] - 3s 863us/step - loss: 0.6718 - accuracy: 0.5806
# Epoch 87/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5810
# Epoch 87: saving model to checkpoints\weights.87.hdf5
# 3696/3696 [==============================] - 3s 867us/step - loss: 0.6718 - accuracy: 0.5808
# Epoch 88/200
# 3668/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5811
# Epoch 88: saving model to checkpoints\weights.88.hdf5
# 3696/3696 [==============================] - 3s 861us/step - loss: 0.6716 - accuracy: 0.5811
# Epoch 89/200
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5802
# Epoch 89: saving model to checkpoints\weights.89.hdf5
# 3696/3696 [==============================] - 3s 885us/step - loss: 0.6717 - accuracy: 0.5803
# Epoch 90/200
# 3667/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5813
# Epoch 90: saving model to checkpoints\weights.90.hdf5
# 3696/3696 [==============================] - 3s 876us/step - loss: 0.6717 - accuracy: 0.5812
# Epoch 91/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5809
# Epoch 91: saving model to checkpoints\weights.91.hdf5
# 3696/3696 [==============================] - 3s 882us/step - loss: 0.6716 - accuracy: 0.5813
# Epoch 92/200
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.5820
# Epoch 92: saving model to checkpoints\weights.92.hdf5
# 3696/3696 [==============================] - 3s 891us/step - loss: 0.6716 - accuracy: 0.5821
# Epoch 93/200
# 3657/3696 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.5818
# Epoch 93: saving model to checkpoints\weights.93.hdf5
# 3696/3696 [==============================] - 3s 892us/step - loss: 0.6716 - accuracy: 0.5819
# Epoch 94/200
# 3641/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5818
# Epoch 94: saving model to checkpoints\weights.94.hdf5
# 3696/3696 [==============================] - 3s 868us/step - loss: 0.6715 - accuracy: 0.5819
# Epoch 95/200
# 3667/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5817
# Epoch 95: saving model to checkpoints\weights.95.hdf5
# 3696/3696 [==============================] - 3s 877us/step - loss: 0.6715 - accuracy: 0.5816
# Epoch 96/200
# 3649/3696 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.5820
# Epoch 96: saving model to checkpoints\weights.96.hdf5
# 3696/3696 [==============================] - 3s 866us/step - loss: 0.6717 - accuracy: 0.5819
# Epoch 97/200
# 3653/3696 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.5824
# Epoch 97: saving model to checkpoints\weights.97.hdf5
# 3696/3696 [==============================] - 3s 895us/step - loss: 0.6716 - accuracy: 0.5823
# Epoch 98/200
# 3649/3696 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.5815
# Epoch 98: saving model to checkpoints\weights.98.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6715 - accuracy: 0.5818
# Epoch 99/200
# 3652/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5820
# Epoch 99: saving model to checkpoints\weights.99.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6715 - accuracy: 0.5820
# Epoch 100/200
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5809
# Epoch 100: saving model to checkpoints\weights.100.hdf5
# 3696/3696 [==============================] - 3s 891us/step - loss: 0.6716 - accuracy: 0.5810
# Epoch 101/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6716 - accuracy: 0.5818
# Epoch 101: saving model to checkpoints\weights.101.hdf5
# 3696/3696 [==============================] - 3s 897us/step - loss: 0.6716 - accuracy: 0.5818
# Epoch 102/200
# 3646/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5814
# Epoch 102: saving model to checkpoints\weights.102.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6716 - accuracy: 0.5811
# Epoch 103/200
# 3682/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5812
# Epoch 103: saving model to checkpoints\weights.103.hdf5
# 3696/3696 [==============================] - 3s 873us/step - loss: 0.6717 - accuracy: 0.5812
# Epoch 104/200
# 3691/3696 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5811
# Epoch 104: saving model to checkpoints\weights.104.hdf5
# 3696/3696 [==============================] - 3s 871us/step - loss: 0.6717 - accuracy: 0.5810
# Epoch 105/200
# 3694/3696 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.5824
# Epoch 105: saving model to checkpoints\weights.105.hdf5
# 3696/3696 [==============================] - 3s 884us/step - loss: 0.6716 - accuracy: 0.5824
# Epoch 106/200
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5821
# Epoch 106: saving model to checkpoints\weights.106.hdf5
# 3696/3696 [==============================] - 3s 872us/step - loss: 0.6716 - accuracy: 0.5820
# Epoch 107/200
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5821
# Epoch 107: saving model to checkpoints\weights.107.hdf5
# 3696/3696 [==============================] - 3s 899us/step - loss: 0.6715 - accuracy: 0.5821
# Epoch 108/200
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5821
# Epoch 108: saving model to checkpoints\weights.108.hdf5
# 3696/3696 [==============================] - 3s 889us/step - loss: 0.6715 - accuracy: 0.5820
# Epoch 109/200
# 3694/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5820
# Epoch 109: saving model to checkpoints\weights.109.hdf5
# 3696/3696 [==============================] - 3s 883us/step - loss: 0.6715 - accuracy: 0.5819
# Epoch 110/200
# 3650/3696 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5818
# Epoch 110: saving model to checkpoints\weights.110.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6713 - accuracy: 0.5819
# Epoch 111/200
# 3678/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5821
# Epoch 111: saving model to checkpoints\weights.111.hdf5
# 3696/3696 [==============================] - 3s 873us/step - loss: 0.6713 - accuracy: 0.5821
# Epoch 112/200
# 3656/3696 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5815
# Epoch 112: saving model to checkpoints\weights.112.hdf5
# 3696/3696 [==============================] - 3s 878us/step - loss: 0.6714 - accuracy: 0.5816
# Epoch 113/200
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5816
# Epoch 113: saving model to checkpoints\weights.113.hdf5
# 3696/3696 [==============================] - 3s 876us/step - loss: 0.6716 - accuracy: 0.5816
# Epoch 114/200
# 3690/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5819
# Epoch 114: saving model to checkpoints\weights.114.hdf5
# 3696/3696 [==============================] - 3s 884us/step - loss: 0.6713 - accuracy: 0.5819
# Epoch 115/200
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5821
# Epoch 115: saving model to checkpoints\weights.115.hdf5
# 3696/3696 [==============================] - 3s 874us/step - loss: 0.6713 - accuracy: 0.5822
# Epoch 116/200
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5825
# Epoch 116: saving model to checkpoints\weights.116.hdf5
# 3696/3696 [==============================] - 3s 888us/step - loss: 0.6714 - accuracy: 0.5823
# Epoch 117/200
# 3683/3696 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.5813
# Epoch 117: saving model to checkpoints\weights.117.hdf5
# 3696/3696 [==============================] - 3s 885us/step - loss: 0.6716 - accuracy: 0.5813
# Epoch 118/200
# 3656/3696 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.5809
# Epoch 118: saving model to checkpoints\weights.118.hdf5
# 3696/3696 [==============================] - 3s 907us/step - loss: 0.6714 - accuracy: 0.5811
# Epoch 119/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6716 - accuracy: 0.5812
# Epoch 119: saving model to checkpoints\weights.119.hdf5
# 3696/3696 [==============================] - 3s 925us/step - loss: 0.6716 - accuracy: 0.5812
# Epoch 120/200
# 3671/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5821
# Epoch 120: saving model to checkpoints\weights.120.hdf5
# 3696/3696 [==============================] - 3s 902us/step - loss: 0.6712 - accuracy: 0.5822
# Epoch 121/200
# 3658/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5822
# Epoch 121: saving model to checkpoints\weights.121.hdf5
# 3696/3696 [==============================] - 3s 892us/step - loss: 0.6713 - accuracy: 0.5822
# Epoch 122/200
# 3671/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5824
# Epoch 122: saving model to checkpoints\weights.122.hdf5
# 3696/3696 [==============================] - 3s 888us/step - loss: 0.6712 - accuracy: 0.5824
# Epoch 123/200
# 3691/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5821
# Epoch 123: saving model to checkpoints\weights.123.hdf5
# 3696/3696 [==============================] - 3s 885us/step - loss: 0.6713 - accuracy: 0.5820
# Epoch 124/200
# 3641/3696 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5812
# Epoch 124: saving model to checkpoints\weights.124.hdf5
# 3696/3696 [==============================] - 3s 896us/step - loss: 0.6713 - accuracy: 0.5812
# Epoch 125/200
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5825
# Epoch 125: saving model to checkpoints\weights.125.hdf5
# 3696/3696 [==============================] - 3s 898us/step - loss: 0.6714 - accuracy: 0.5825
# Epoch 126/200
# 3670/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5818
# Epoch 126: saving model to checkpoints\weights.126.hdf5
# 3696/3696 [==============================] - 3s 903us/step - loss: 0.6712 - accuracy: 0.5818
# Epoch 127/200
# 3690/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5826
# Epoch 127: saving model to checkpoints\weights.127.hdf5
# 3696/3696 [==============================] - 3s 885us/step - loss: 0.6712 - accuracy: 0.5826
# Epoch 128/200
# 3663/3696 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5824
# Epoch 128: saving model to checkpoints\weights.128.hdf5
# 3696/3696 [==============================] - 3s 891us/step - loss: 0.6713 - accuracy: 0.5827
# Epoch 129/200
# 3683/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5821
# Epoch 129: saving model to checkpoints\weights.129.hdf5
# 3696/3696 [==============================] - 3s 872us/step - loss: 0.6712 - accuracy: 0.5821
# Epoch 130/200
# 3655/3696 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5814
# Epoch 130: saving model to checkpoints\weights.130.hdf5
# 3696/3696 [==============================] - 3s 894us/step - loss: 0.6714 - accuracy: 0.5815
# Epoch 131/200
# 3666/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5822
# Epoch 131: saving model to checkpoints\weights.131.hdf5
# 3696/3696 [==============================] - 3s 890us/step - loss: 0.6713 - accuracy: 0.5822
# Epoch 132/200
# 3694/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5820
# Epoch 132: saving model to checkpoints\weights.132.hdf5
# 3696/3696 [==============================] - 3s 885us/step - loss: 0.6713 - accuracy: 0.5820
# Epoch 133/200
# 3651/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5822
# Epoch 133: saving model to checkpoints\weights.133.hdf5
# 3696/3696 [==============================] - 3s 935us/step - loss: 0.6713 - accuracy: 0.5822
# Epoch 134/200
# 3685/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5822
# Epoch 134: saving model to checkpoints\weights.134.hdf5
# 3696/3696 [==============================] - 3s 872us/step - loss: 0.6711 - accuracy: 0.5822
# Epoch 135/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6712 - accuracy: 0.5823
# Epoch 135: saving model to checkpoints\weights.135.hdf5
# 3696/3696 [==============================] - 3s 869us/step - loss: 0.6712 - accuracy: 0.5823
# Epoch 136/200
# 3682/3696 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5817
# Epoch 136: saving model to checkpoints\weights.136.hdf5
# 3696/3696 [==============================] - 3s 872us/step - loss: 0.6714 - accuracy: 0.5818
# Epoch 137/200
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5828
# Epoch 137: saving model to checkpoints\weights.137.hdf5
# 3696/3696 [==============================] - 3s 888us/step - loss: 0.6711 - accuracy: 0.5828
# Epoch 138/200
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5830
# Epoch 138: saving model to checkpoints\weights.138.hdf5
# 3696/3696 [==============================] - 3s 887us/step - loss: 0.6714 - accuracy: 0.5828
# Epoch 139/200
# 3662/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5826
# Epoch 139: saving model to checkpoints\weights.139.hdf5
# 3696/3696 [==============================] - 3s 890us/step - loss: 0.6711 - accuracy: 0.5827
# Epoch 140/200
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5827
# Epoch 140: saving model to checkpoints\weights.140.hdf5
# 3696/3696 [==============================] - 3s 887us/step - loss: 0.6712 - accuracy: 0.5827
# Epoch 141/200
# 3638/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5832
# Epoch 141: saving model to checkpoints\weights.141.hdf5
# 3696/3696 [==============================] - 3s 869us/step - loss: 0.6711 - accuracy: 0.5830
# Epoch 142/200
# 3691/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5824
# Epoch 142: saving model to checkpoints\weights.142.hdf5
# 3696/3696 [==============================] - 3s 884us/step - loss: 0.6712 - accuracy: 0.5824
# Epoch 143/200
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5822
# Epoch 143: saving model to checkpoints\weights.143.hdf5
# 3696/3696 [==============================] - 3s 856us/step - loss: 0.6713 - accuracy: 0.5822
# Epoch 144/200
# 3648/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5824
# Epoch 144: saving model to checkpoints\weights.144.hdf5
# 3696/3696 [==============================] - 3s 867us/step - loss: 0.6712 - accuracy: 0.5825
# Epoch 145/200
# 3652/3696 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5826
# Epoch 145: saving model to checkpoints\weights.145.hdf5
# 3696/3696 [==============================] - 3s 880us/step - loss: 0.6713 - accuracy: 0.5825
# Epoch 146/200
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.5824
# Epoch 146: saving model to checkpoints\weights.146.hdf5
# 3696/3696 [==============================] - 3s 859us/step - loss: 0.6712 - accuracy: 0.5825
# Epoch 147/200
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5829
# Epoch 147: saving model to checkpoints\weights.147.hdf5
# 3696/3696 [==============================] - 3s 873us/step - loss: 0.6711 - accuracy: 0.5827
# Epoch 148/200
# 3665/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5830
# Epoch 148: saving model to checkpoints\weights.148.hdf5
# 3696/3696 [==============================] - 3s 876us/step - loss: 0.6710 - accuracy: 0.5830
# Epoch 149/200
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5821
# Epoch 149: saving model to checkpoints\weights.149.hdf5
# 3696/3696 [==============================] - 3s 869us/step - loss: 0.6711 - accuracy: 0.5821
# Epoch 150/200
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5820
# Epoch 150: saving model to checkpoints\weights.150.hdf5
# 3696/3696 [==============================] - 3s 856us/step - loss: 0.6711 - accuracy: 0.5821
# Epoch 151/200
# 3650/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5830
# Epoch 151: saving model to checkpoints\weights.151.hdf5
# 3696/3696 [==============================] - 3s 851us/step - loss: 0.6709 - accuracy: 0.5828
# Epoch 152/200
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5825
# Epoch 152: saving model to checkpoints\weights.152.hdf5
# 3696/3696 [==============================] - 3s 847us/step - loss: 0.6711 - accuracy: 0.5824
# Epoch 153/200
# 3694/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5829
# Epoch 153: saving model to checkpoints\weights.153.hdf5
# 3696/3696 [==============================] - 3s 870us/step - loss: 0.6710 - accuracy: 0.5829
# Epoch 154/200
# 3642/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5834
# Epoch 154: saving model to checkpoints\weights.154.hdf5
# 3696/3696 [==============================] - 3s 853us/step - loss: 0.6711 - accuracy: 0.5835
# Epoch 155/200
# 3642/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5820
# Epoch 155: saving model to checkpoints\weights.155.hdf5
# 3696/3696 [==============================] - 3s 867us/step - loss: 0.6711 - accuracy: 0.5820
# Epoch 156/200
# 3639/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5834
# Epoch 156: saving model to checkpoints\weights.156.hdf5
# 3696/3696 [==============================] - 3s 854us/step - loss: 0.6711 - accuracy: 0.5837
# Epoch 157/200
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6707 - accuracy: 0.5839
# Epoch 157: saving model to checkpoints\weights.157.hdf5
# 3696/3696 [==============================] - 3s 864us/step - loss: 0.6709 - accuracy: 0.5837
# Epoch 158/200
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6709 - accuracy: 0.5839
# Epoch 158: saving model to checkpoints\weights.158.hdf5
# 3696/3696 [==============================] - 3s 897us/step - loss: 0.6709 - accuracy: 0.5839
# Epoch 159/200
# 3642/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5829
# Epoch 159: saving model to checkpoints\weights.159.hdf5
# 3696/3696 [==============================] - 3s 854us/step - loss: 0.6711 - accuracy: 0.5828
# Epoch 160/200
# 3683/3696 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.5830
# Epoch 160: saving model to checkpoints\weights.160.hdf5
# 3696/3696 [==============================] - 3s 844us/step - loss: 0.6711 - accuracy: 0.5833
# Epoch 161/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5834
# Epoch 161: saving model to checkpoints\weights.161.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6710 - accuracy: 0.5833
# Epoch 162/200
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5835
# Epoch 162: saving model to checkpoints\weights.162.hdf5
# 3696/3696 [==============================] - 3s 847us/step - loss: 0.6709 - accuracy: 0.5833
# Epoch 163/200
# 3646/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5839
# Epoch 163: saving model to checkpoints\weights.163.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6709 - accuracy: 0.5836
# Epoch 164/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5838
# Epoch 164: saving model to checkpoints\weights.164.hdf5
# 3696/3696 [==============================] - 3s 895us/step - loss: 0.6709 - accuracy: 0.5838
# Epoch 165/200
# 3663/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5847
# Epoch 165: saving model to checkpoints\weights.165.hdf5
# 3696/3696 [==============================] - 3s 877us/step - loss: 0.6711 - accuracy: 0.5844
# Epoch 166/200
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5830
# Epoch 166: saving model to checkpoints\weights.166.hdf5
# 3696/3696 [==============================] - 3s 891us/step - loss: 0.6710 - accuracy: 0.5831
# Epoch 167/200
# 3643/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5834
# Epoch 167: saving model to checkpoints\weights.167.hdf5
# 3696/3696 [==============================] - 4s 952us/step - loss: 0.6710 - accuracy: 0.5834
# Epoch 168/200
# 3654/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5844
# Epoch 168: saving model to checkpoints\weights.168.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6709 - accuracy: 0.5844
# Epoch 169/200
# 3653/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5836
# Epoch 169: saving model to checkpoints\weights.169.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6708 - accuracy: 0.5837
# Epoch 170/200
# 3655/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5837
# Epoch 170: saving model to checkpoints\weights.170.hdf5
# 3696/3696 [==============================] - 3s 880us/step - loss: 0.6710 - accuracy: 0.5838
# Epoch 171/200
# 3640/3696 [============================>.] - ETA: 0s - loss: 0.6707 - accuracy: 0.5827
# Epoch 171: saving model to checkpoints\weights.171.hdf5
# 3696/3696 [==============================] - 3s 881us/step - loss: 0.6707 - accuracy: 0.5828
# Epoch 172/200
# 3638/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5840
# Epoch 172: saving model to checkpoints\weights.172.hdf5
# 3696/3696 [==============================] - 3s 882us/step - loss: 0.6710 - accuracy: 0.5838
# Epoch 173/200
# 3695/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5834
# Epoch 173: saving model to checkpoints\weights.173.hdf5
# 3696/3696 [==============================] - 3s 870us/step - loss: 0.6710 - accuracy: 0.5834
# Epoch 174/200
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5825
# Epoch 174: saving model to checkpoints\weights.174.hdf5
# 3696/3696 [==============================] - 3s 874us/step - loss: 0.6708 - accuracy: 0.5827
# Epoch 175/200
# 3661/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5846
# Epoch 175: saving model to checkpoints\weights.175.hdf5
# 3696/3696 [==============================] - 3s 849us/step - loss: 0.6708 - accuracy: 0.5848
# Epoch 176/200
# 3652/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5851
# Epoch 176: saving model to checkpoints\weights.176.hdf5
# 3696/3696 [==============================] - 3s 852us/step - loss: 0.6708 - accuracy: 0.5850
# Epoch 177/200
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5831
# Epoch 177: saving model to checkpoints\weights.177.hdf5
# 3696/3696 [==============================] - 3s 860us/step - loss: 0.6709 - accuracy: 0.5831
# Epoch 178/200
# 3647/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5838
# Epoch 178: saving model to checkpoints\weights.178.hdf5
# 3696/3696 [==============================] - 3s 868us/step - loss: 0.6710 - accuracy: 0.5840
# Epoch 179/200
# 3661/3696 [============================>.] - ETA: 0s - loss: 0.6706 - accuracy: 0.5833
# Epoch 179: saving model to checkpoints\weights.179.hdf5
# 3696/3696 [==============================] - 3s 878us/step - loss: 0.6708 - accuracy: 0.5831
# Epoch 180/200
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5841
# Epoch 180: saving model to checkpoints\weights.180.hdf5
# 3696/3696 [==============================] - 3s 859us/step - loss: 0.6709 - accuracy: 0.5841
# Epoch 181/200
# 3656/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5846
# Epoch 181: saving model to checkpoints\weights.181.hdf5
# 3696/3696 [==============================] - 3s 894us/step - loss: 0.6709 - accuracy: 0.5847
# Epoch 182/200
# 3650/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5843
# Epoch 182: saving model to checkpoints\weights.182.hdf5
# 3696/3696 [==============================] - 3s 879us/step - loss: 0.6709 - accuracy: 0.5843
# Epoch 183/200
# 3669/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5836
# Epoch 183: saving model to checkpoints\weights.183.hdf5
# 3696/3696 [==============================] - 3s 876us/step - loss: 0.6711 - accuracy: 0.5839
# Epoch 184/200
# 3667/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5849
# Epoch 184: saving model to checkpoints\weights.184.hdf5
# 3696/3696 [==============================] - 3s 890us/step - loss: 0.6708 - accuracy: 0.5850
# Epoch 185/200
# 3678/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5846
# Epoch 185: saving model to checkpoints\weights.185.hdf5
# 3696/3696 [==============================] - 3s 887us/step - loss: 0.6708 - accuracy: 0.5847
# Epoch 186/200
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5848
# Epoch 186: saving model to checkpoints\weights.186.hdf5
# 3696/3696 [==============================] - 3s 897us/step - loss: 0.6709 - accuracy: 0.5848
# Epoch 187/200
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5856
# Epoch 187: saving model to checkpoints\weights.187.hdf5
# 3696/3696 [==============================] - 3s 871us/step - loss: 0.6709 - accuracy: 0.5857
# Epoch 188/200
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5840
# Epoch 188: saving model to checkpoints\weights.188.hdf5
# 3696/3696 [==============================] - 3s 890us/step - loss: 0.6709 - accuracy: 0.5842
# Epoch 189/200
# 3691/3696 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5846
# Epoch 189: saving model to checkpoints\weights.189.hdf5
# 3696/3696 [==============================] - 3s 856us/step - loss: 0.6711 - accuracy: 0.5846
# Epoch 190/200
# 3653/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5842
# Epoch 190: saving model to checkpoints\weights.190.hdf5
# 3696/3696 [==============================] - 4s 963us/step - loss: 0.6707 - accuracy: 0.5846
# Epoch 191/200
# 3644/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5841
# Epoch 191: saving model to checkpoints\weights.191.hdf5
# 3696/3696 [==============================] - 3s 910us/step - loss: 0.6709 - accuracy: 0.5843
# Epoch 192/200
# 3648/3696 [============================>.] - ETA: 0s - loss: 0.6707 - accuracy: 0.5861
# Epoch 192: saving model to checkpoints\weights.192.hdf5
# 3696/3696 [==============================] - 4s 949us/step - loss: 0.6707 - accuracy: 0.5862
# Epoch 193/200
# 3656/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5837
# Epoch 193: saving model to checkpoints\weights.193.hdf5
# 3696/3696 [==============================] - 3s 906us/step - loss: 0.6708 - accuracy: 0.5839
# Epoch 194/200
# 3659/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5861
# Epoch 194: saving model to checkpoints\weights.194.hdf5
# 3696/3696 [==============================] - 3s 865us/step - loss: 0.6709 - accuracy: 0.5860
# Epoch 195/200
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.5851
# Epoch 195: saving model to checkpoints\weights.195.hdf5
# 3696/3696 [==============================] - 4s 956us/step - loss: 0.6711 - accuracy: 0.5850
# Epoch 196/200
# 3648/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5850
# Epoch 196: saving model to checkpoints\weights.196.hdf5
# 3696/3696 [==============================] - 3s 937us/step - loss: 0.6709 - accuracy: 0.5848
# Epoch 197/200
# 3661/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5851
# Epoch 197: saving model to checkpoints\weights.197.hdf5
# 3696/3696 [==============================] - 3s 932us/step - loss: 0.6709 - accuracy: 0.5850
# Epoch 198/200
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5847
# Epoch 198: saving model to checkpoints\weights.198.hdf5
# 3696/3696 [==============================] - 3s 928us/step - loss: 0.6708 - accuracy: 0.5848
# Epoch 199/200
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6708 - accuracy: 0.5853
# Epoch 199: saving model to checkpoints\weights.199.hdf5
# 3696/3696 [==============================] - 3s 889us/step - loss: 0.6708 - accuracy: 0.5853
# Epoch 200/200
# 3670/3696 [============================>.] - ETA: 0s - loss: 0.6707 - accuracy: 0.5857
# Epoch 200: saving model to checkpoints\weights.200.hdf5
# 3696/3696 [==============================] - 3s 902us/step - loss: 0.6707 - accuracy: 0.5858

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1232/1232 - 1s - loss: 0.6727 - accuracy: 0.5784 - 837ms/epoch - 679us/step
# Loss: 0.6727356910705566, Accuracy: 0.5783652067184448

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")

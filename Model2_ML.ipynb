# %% [markdown]
# # Preprocessing the Data for a Neural Network

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd

# Import and read the charity_data.csv.
df = pd.read_csv('model_df1_official.csv')
df.head()
# Out:
#    Unnamed: 0  spend  Impressions  leads  State Tiers  Agency Tiers
# 0         770   7.28          427    0.0            4             4
# 1         771  13.32         1042    1.0            4             4
# 2         772  10.11          337    0.0            4             4
# 3         773   0.00            0    1.0            4             4
# 4         774   7.35          379    1.0            4             4

# %% [markdown]
# # Split into train and test features

# %%
# Split our preprocessed data into our features and target arrays
y = model_df1_official['leads'].values
X = model_df1_official.drop(['leads'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\dia78039\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train, Evaluate our Model 1 - NN

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# using multi-layer perceptron (two layers)
numInputFeatures = len(X_train[0])

# I have 19k columns
# layer1 = input layer, typically equals number of input variables in data
layer1 = 20
# layer 2 = hidden layer, typically 2/3 of input layer
layer2 = 10
# layer 3 = hidden layer
layer3= 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=layer1, 
                          input_dim=numInputFeatures, 
                          activation="relu")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, 
                             activation="relu"))

# adding a third layer to increase accuracy 
nn.add(tf.keras.layers.Dense(units=layer3, 
                             activation='relu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                100
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 371
# Trainable params: 371
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    # checkpoint directory and file structure defined above
    filepath=checkpoint_path,
    # notified when checkpoint is being saved to the directory
    verbose=1,
    # checkpoint files take small space
    save_weights_only=True,
    # checkpoints saved every epoch
    save_freq='epoch')

# %%
# Train the model
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 3689/3696 [============================>.] - ETA: 0s - loss: 0.6843 - accuracy: 0.5626
# Epoch 1: saving model to checkpoints\weights.01.hdf5
# 3696/3696 [==============================] - 8s 2ms/step - loss: 0.6843 - accuracy: 0.5627
# Epoch 2/100
# 3682/3696 [============================>.] - ETA: 0s - loss: 0.6833 - accuracy: 0.5642
# Epoch 2: saving model to checkpoints\weights.02.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6833 - accuracy: 0.5643
# Epoch 3/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6830 - accuracy: 0.5644
# Epoch 3: saving model to checkpoints\weights.03.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6830 - accuracy: 0.5644
# Epoch 4/100
# 3679/3696 [============================>.] - ETA: 0s - loss: 0.6828 - accuracy: 0.5648
# Epoch 4: saving model to checkpoints\weights.04.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6828 - accuracy: 0.5647
# Epoch 5/100
# 3688/3696 [============================>.] - ETA: 0s - loss: 0.6827 - accuracy: 0.5650
# Epoch 5: saving model to checkpoints\weights.05.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6827 - accuracy: 0.5650
# Epoch 6/100
# 3693/3696 [============================>.] - ETA: 0s - loss: 0.6826 - accuracy: 0.5650
# Epoch 6: saving model to checkpoints\weights.06.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6826 - accuracy: 0.5650
# Epoch 7/100
# 3690/3696 [============================>.] - ETA: 0s - loss: 0.6825 - accuracy: 0.5654
# Epoch 7: saving model to checkpoints\weights.07.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6825 - accuracy: 0.5653
# Epoch 8/100
# 3673/3696 [============================>.] - ETA: 0s - loss: 0.6825 - accuracy: 0.5652
# Epoch 8: saving model to checkpoints\weights.08.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6825 - accuracy: 0.5651
# Epoch 9/100
# 3672/3696 [============================>.] - ETA: 0s - loss: 0.6825 - accuracy: 0.5657
# Epoch 9: saving model to checkpoints\weights.09.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6825 - accuracy: 0.5657
# Epoch 10/100
# 3682/3696 [============================>.] - ETA: 0s - loss: 0.6824 - accuracy: 0.5659
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6825 - accuracy: 0.5658
# Epoch 11/100
# 3696/3696 [==============================] - ETA: 0s - loss: 0.6824 - accuracy: 0.5655
# Epoch 11: saving model to checkpoints\weights.11.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6824 - accuracy: 0.5655
# Epoch 12/100
# 3687/3696 [============================>.] - ETA: 0s - loss: 0.6823 - accuracy: 0.5656
# Epoch 12: saving model to checkpoints\weights.12.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6824 - accuracy: 0.5656
# Epoch 13/100
# 3671/3696 [============================>.] - ETA: 0s - loss: 0.6824 - accuracy: 0.5657
# Epoch 13: saving model to checkpoints\weights.13.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6823 - accuracy: 0.5660
# Epoch 14/100
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6825 - accuracy: 0.5659
# Epoch 14: saving model to checkpoints\weights.14.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6825 - accuracy: 0.5661
# Epoch 15/100
# 3687/3696 [============================>.] - ETA: 0s - loss: 0.6823 - accuracy: 0.5661
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6823 - accuracy: 0.5660
# Epoch 16/100
# 3671/3696 [============================>.] - ETA: 0s - loss: 0.6822 - accuracy: 0.5663
# Epoch 16: saving model to checkpoints\weights.16.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6823 - accuracy: 0.5661
# Epoch 17/100
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6822 - accuracy: 0.5661
# Epoch 17: saving model to checkpoints\weights.17.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6822 - accuracy: 0.5660
# Epoch 18/100
# 3675/3696 [============================>.] - ETA: 0s - loss: 0.6822 - accuracy: 0.5660
# Epoch 18: saving model to checkpoints\weights.18.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6822 - accuracy: 0.5661
# Epoch 19/100
# 3694/3696 [============================>.] - ETA: 0s - loss: 0.6821 - accuracy: 0.5663
# Epoch 19: saving model to checkpoints\weights.19.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6821 - accuracy: 0.5663
# Epoch 20/100
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6822 - accuracy: 0.5661
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6822 - accuracy: 0.5662
# Epoch 21/100
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6821 - accuracy: 0.5661
# Epoch 21: saving model to checkpoints\weights.21.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6822 - accuracy: 0.5661
# Epoch 22/100
# 3684/3696 [============================>.] - ETA: 0s - loss: 0.6821 - accuracy: 0.5663
# Epoch 22: saving model to checkpoints\weights.22.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6821 - accuracy: 0.5664
# Epoch 23/100
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6821 - accuracy: 0.5664
# Epoch 23: saving model to checkpoints\weights.23.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6821 - accuracy: 0.5664
# Epoch 24/100
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6822 - accuracy: 0.5661
# Epoch 24: saving model to checkpoints\weights.24.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6822 - accuracy: 0.5661
# Epoch 25/100
# 3675/3696 [============================>.] - ETA: 0s - loss: 0.6820 - accuracy: 0.5661
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6820 - accuracy: 0.5661
# Epoch 26/100
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6820 - accuracy: 0.5661
# Epoch 26: saving model to checkpoints\weights.26.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6820 - accuracy: 0.5661
# Epoch 27/100
# 3675/3696 [============================>.] - ETA: 0s - loss: 0.6820 - accuracy: 0.5663
# Epoch 27: saving model to checkpoints\weights.27.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6820 - accuracy: 0.5664
# Epoch 28/100
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6820 - accuracy: 0.5658
# Epoch 28: saving model to checkpoints\weights.28.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6820 - accuracy: 0.5659
# Epoch 29/100
# 3676/3696 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.5662
# Epoch 29: saving model to checkpoints\weights.29.hdf5
# 3696/3696 [==============================] - 7s 2ms/step - loss: 0.6819 - accuracy: 0.5662
# Epoch 30/100
# 3690/3696 [============================>.] - ETA: 0s - loss: 0.6819 - accuracy: 0.5660
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6819 - accuracy: 0.5660
# Epoch 31/100
# 3664/3696 [============================>.] - ETA: 0s - loss: 0.6819 - accuracy: 0.5657
# Epoch 31: saving model to checkpoints\weights.31.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6819 - accuracy: 0.5659
# Epoch 32/100
# 3674/3696 [============================>.] - ETA: 0s - loss: 0.6819 - accuracy: 0.5663
# Epoch 32: saving model to checkpoints\weights.32.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6819 - accuracy: 0.5663
# Epoch 33/100
# 3667/3696 [============================>.] - ETA: 0s - loss: 0.6819 - accuracy: 0.5661
# Epoch 33: saving model to checkpoints\weights.33.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6819 - accuracy: 0.5662
# Epoch 34/100
# 3656/3696 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.5661
# Epoch 34: saving model to checkpoints\weights.34.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6818 - accuracy: 0.5662
# Epoch 35/100
# 3689/3696 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.5662
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6818 - accuracy: 0.5662
# Epoch 36/100
# 3677/3696 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.5664
# Epoch 36: saving model to checkpoints\weights.36.hdf5
# 3696/3696 [==============================] - 5s 1ms/step - loss: 0.6818 - accuracy: 0.5664
# Epoch 37/100
# 3692/3696 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.5663
# Epoch 37: saving model to checkpoints\weights.37.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6818 - accuracy: 0.5663
# Epoch 38/100
# 3684/3696 [============================>.] - ETA: 0s - loss: 0.6817 - accuracy: 0.5664
# Epoch 38: saving model to checkpoints\weights.38.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6817 - accuracy: 0.5664
# Epoch 39/100
# 3686/3696 [============================>.] - ETA: 0s - loss: 0.6817 - accuracy: 0.5662
# Epoch 39: saving model to checkpoints\weights.39.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6817 - accuracy: 0.5663
# Epoch 40/100
# 3678/3696 [============================>.] - ETA: 0s - loss: 0.6816 - accuracy: 0.5666
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 3696/3696 [==============================] - 6s 2ms/step - loss: 0.6817 - accuracy: 0.5663
# Epoch 41/100
# 2201/3696 [================>.............] - ETA: 2s - loss: 0.6813 - accuracy: 0.5665

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# # Export the model to HDF5 file
# nn.save("AlphabetSoupCharity_optimization.h5")
